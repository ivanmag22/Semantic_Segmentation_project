# %% [markdown]
# ## **Installing packages**

# %%
# !pip3 install torch torchvision torchaudio
# !pip install 'tqdm'
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.2)

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (23.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2

# %% [markdown]
# ## **Libraries**

# %%
import os
import os.path
import sys
import logging

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader, Dataset
from torch.backends import cudnn
import torch.cuda.amp as amp
from torch.autograd import Function
import torch.nn.functional as F

import torchvision
from torchvision.transforms import transforms
#from torchvision.models import alexnet

from PIL import Image
from tqdm import tqdm
import numpy as np
from tensorboardX import SummaryWriter

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import random

from pathlib import Path
import json
import random


logger = logging.getLogger()

# %% [markdown]
# ## **Import**

# %% [markdown]
# ### Importing datasets

# %%
from google.colab import drive

drive.mount('/content/Drive')

cityscapes = True
gta5 = True

if not os.path.isdir(f'/content/Cityscapes') and cityscapes:
  # !jar xvf  "/content/Drive/MyDrive/Colab Notebooks/AML/Cityscapes.zip"
if not os.path.isdir(f'/content/GTA5') and gta5:
  # !jar xvf  "/content/Drive/MyDrive/Colab Notebooks/AML/GTA5.zip"
# Out:
# Output streaming troncato alle ultime 5000 righe.
#  inflated: GTA5/images/00002.png
#  inflated: GTA5/images/00003.png
#  inflated: GTA5/images/00004.png
#  inflated: GTA5/images/00005.png
#  inflated: GTA5/images/00006.png
#  inflated: GTA5/images/00007.png
#  inflated: GTA5/images/00008.png
#  inflated: GTA5/images/00009.png
#  inflated: GTA5/images/00010.png
#  inflated: GTA5/images/00011.png
#  inflated: GTA5/images/00012.png
#  inflated: GTA5/images/00013.png
#  inflated: GTA5/images/00014.png
#  inflated: GTA5/images/00015.png
#  inflated: GTA5/images/00016.png
#  inflated: GTA5/images/00017.png
#  inflated: GTA5/images/00018.png
#  inflated: GTA5/images/00019.png
#  inflated: GTA5/images/00020.png
#  inflated: GTA5/images/00021.png
#  inflated: GTA5/images/00022.png
#  inflated: GTA5/images/00023.png
#  inflated: GTA5/images/00024.png
#  inflated: GTA5/images/00025.png
#  inflated: GTA5/images/00026.png
#  inflated: GTA5/images/00027.png
#  inflated: GTA5/images/00028.png
#  inflated: GTA5/images/00029.png
#  inflated: GTA5/images/00030.png
#  inflated: GTA5/images/00031.png
#  inflated: GTA5/images/00032.png
#  inflated: GTA5/images/00033.png
#  inflated: GTA5/images/00034.png
#  inflated: GTA5/images/00035.png
#  inflated: GTA5/images/00036.png
#  inflated: GTA5/images/00037.png
#  inflated: GTA5/images/00038.png
#  inflated: GTA5/images/00039.png
#  inflated: GTA5/images/00040.png
#  inflated: GTA5/images/00041.png
#  inflated: GTA5/images/00042.png
#  inflated: GTA5/images/00043.png
#  inflated: GTA5/images/00044.png
#  inflated: GTA5/images/00045.png
#  inflated: GTA5/images/00046.png
#  inflated: GTA5/images/00047.png
#  inflated: GTA5/images/00048.png
#  inflated: GTA5/images/00049.png
#  inflated: GTA5/images/00050.png
#  inflated: GTA5/images/00051.png
#  inflated: GTA5/images/00052.png
#  inflated: GTA5/images/00053.png
#  inflated: GTA5/images/00054.png
#  inflated: GTA5/images/00055.png
#  inflated: GTA5/images/00056.png
#  inflated: GTA5/images/00057.png
#  inflated: GTA5/images/00058.png
#  inflated: GTA5/images/00059.png
#  inflated: GTA5/images/00060.png
#  inflated: GTA5/images/00061.png
#  inflated: GTA5/images/00062.png
#  inflated: GTA5/images/00063.png
#  inflated: GTA5/images/00064.png
#  inflated: GTA5/images/00065.png
#  inflated: GTA5/images/00066.png
#  inflated: GTA5/images/00067.png
#  inflated: GTA5/images/00068.png
#  inflated: GTA5/images/00069.png
#  inflated: GTA5/images/00070.png
#  inflated: GTA5/images/00071.png
#  inflated: GTA5/images/00072.png
#  inflated: GTA5/images/00073.png
#  inflated: GTA5/images/00074.png
#  inflated: GTA5/images/00075.png
#  inflated: GTA5/images/00076.png
#  inflated: GTA5/images/00077.png
#  inflated: GTA5/images/00078.png
#  inflated: GTA5/images/00079.png
#  inflated: GTA5/images/00080.png
#  inflated: GTA5/images/00081.png
#  inflated: GTA5/images/00082.png
#  inflated: GTA5/images/00083.png
#  inflated: GTA5/images/00084.png
#  inflated: GTA5/images/00085.png
#  inflated: GTA5/images/00086.png
#  inflated: GTA5/images/00087.png
#  inflated: GTA5/images/00088.png
#  inflated: GTA5/images/00089.png
#  inflated: GTA5/images/00090.png
#  inflated: GTA5/images/00091.png
#  inflated: GTA5/images/00092.png
#  inflated: GTA5/images/00093.png
#  inflated: GTA5/images/00094.png
#  inflated: GTA5/images/00095.png
#  inflated: GTA5/images/00096.png
#  inflated: GTA5/images/00097.png
#  inflated: GTA5/images/00098.png
#  inflated: GTA5/images/00099.png
#  inflated: GTA5/images/00100.png
#  inflated: GTA5/images/00101.png
#  inflated: GTA5/images/00102.png
#  inflated: GTA5/images/00103.png
#  inflated: GTA5/images/00104.png
#  inflated: GTA5/images/00105.png
#  inflated: GTA5/images/00106.png
#  inflated: GTA5/images/00107.png
#  inflated: GTA5/images/00108.png
#  inflated: GTA5/images/00109.png
#  inflated: GTA5/images/00110.png
#  inflated: GTA5/images/00111.png
#  inflated: GTA5/images/00112.png
#  inflated: GTA5/images/00113.png
#  inflated: GTA5/images/00114.png
#  inflated: GTA5/images/00115.png
#  inflated: GTA5/images/00116.png
#  inflated: GTA5/images/00117.png
#  inflated: GTA5/images/00118.png
#  inflated: GTA5/images/00119.png
#  inflated: GTA5/images/00120.png
#  inflated: GTA5/images/00121.png
#  inflated: GTA5/images/00122.png
#  inflated: GTA5/images/00123.png
#  inflated: GTA5/images/00124.png
#  inflated: GTA5/images/00125.png
#  inflated: GTA5/images/00126.png
#  inflated: GTA5/images/00127.png
#  inflated: GTA5/images/00128.png
#  inflated: GTA5/images/00129.png
#  inflated: GTA5/images/00130.png
#  inflated: GTA5/images/00131.png
#  inflated: GTA5/images/00132.png
#  inflated: GTA5/images/00133.png
#  inflated: GTA5/images/00134.png
#  inflated: GTA5/images/00135.png
#  inflated: GTA5/images/00136.png
#  inflated: GTA5/images/00137.png
#  inflated: GTA5/images/00138.png
#  inflated: GTA5/images/00139.png
#  inflated: GTA5/images/00140.png
#  inflated: GTA5/images/00141.png
#  inflated: GTA5/images/00142.png
#  inflated: GTA5/images/00143.png
#  inflated: GTA5/images/00144.png
#  inflated: GTA5/images/00145.png
#  inflated: GTA5/images/00146.png
#  inflated: GTA5/images/00147.png
#  inflated: GTA5/images/00148.png
#  inflated: GTA5/images/00149.png
#  inflated: GTA5/images/00150.png
#  inflated: GTA5/images/00151.png
#  inflated: GTA5/images/00152.png
#  inflated: GTA5/images/00153.png
#  inflated: GTA5/images/00154.png
#  inflated: GTA5/images/00155.png
#  inflated: GTA5/images/00156.png
#  inflated: GTA5/images/00157.png
#  inflated: GTA5/images/00158.png
#  inflated: GTA5/images/00159.png
#  inflated: GTA5/images/00160.png
#  inflated: GTA5/images/00161.png
#  inflated: GTA5/images/00162.png
#  inflated: GTA5/images/00163.png
#  inflated: GTA5/images/00164.png
#  inflated: GTA5/images/00165.png
#  inflated: GTA5/images/00166.png
#  inflated: GTA5/images/00167.png
#  inflated: GTA5/images/00168.png
#  inflated: GTA5/images/00169.png
#  inflated: GTA5/images/00170.png
#  inflated: GTA5/images/00171.png
#  inflated: GTA5/images/00172.png
#  inflated: GTA5/images/00173.png
#  inflated: GTA5/images/00174.png
#  inflated: GTA5/images/00175.png
#  inflated: GTA5/images/00176.png
#  inflated: GTA5/images/00177.png
#  inflated: GTA5/images/00178.png
#  inflated: GTA5/images/00179.png
#  inflated: GTA5/images/00180.png
#  inflated: GTA5/images/00181.png
#  inflated: GTA5/images/00182.png
#  inflated: GTA5/images/00183.png
#  inflated: GTA5/images/00184.png
#  inflated: GTA5/images/00185.png
#  inflated: GTA5/images/00186.png
#  inflated: GTA5/images/00187.png
#  inflated: GTA5/images/00188.png
#  inflated: GTA5/images/00189.png
#  inflated: GTA5/images/00190.png
#  inflated: GTA5/images/00191.png
#  inflated: GTA5/images/00192.png
#  inflated: GTA5/images/00193.png
#  inflated: GTA5/images/00194.png
#  inflated: GTA5/images/00195.png
#  inflated: GTA5/images/00196.png
#  inflated: GTA5/images/00197.png
#  inflated: GTA5/images/00198.png
#  inflated: GTA5/images/00199.png
#  inflated: GTA5/images/00200.png
#  inflated: GTA5/images/00201.png
#  inflated: GTA5/images/00202.png
#  inflated: GTA5/images/00203.png
#  inflated: GTA5/images/00204.png
#  inflated: GTA5/images/00205.png
#  inflated: GTA5/images/00206.png
#  inflated: GTA5/images/00207.png
#  inflated: GTA5/images/00208.png
#  inflated: GTA5/images/00209.png
#  inflated: GTA5/images/00210.png
#  inflated: GTA5/images/00211.png
#  inflated: GTA5/images/00212.png
#  inflated: GTA5/images/00213.png
#  inflated: GTA5/images/00214.png
#  inflated: GTA5/images/00215.png
#  inflated: GTA5/images/00216.png
#  inflated: GTA5/images/00217.png
#  inflated: GTA5/images/00218.png
#  inflated: GTA5/images/00219.png
#  inflated: GTA5/images/00220.png
#  inflated: GTA5/images/00221.png
#  inflated: GTA5/images/00222.png
#  inflated: GTA5/images/00223.png
#  inflated: GTA5/images/00224.png
#  inflated: GTA5/images/00225.png
#  inflated: GTA5/images/00226.png
#  inflated: GTA5/images/00227.png
#  inflated: GTA5/images/00228.png
#  inflated: GTA5/images/00229.png
#  inflated: GTA5/images/00230.png
#  inflated: GTA5/images/00231.png
#  inflated: GTA5/images/00232.png
#  inflated: GTA5/images/00233.png
#  inflated: GTA5/images/00234.png
#  inflated: GTA5/images/00235.png
#  inflated: GTA5/images/00236.png
#  inflated: GTA5/images/00237.png
#  inflated: GTA5/images/00238.png
#  inflated: GTA5/images/00239.png
#  inflated: GTA5/images/00240.png
#  inflated: GTA5/images/00241.png
#  inflated: GTA5/images/00242.png
#  inflated: GTA5/images/00243.png
#  inflated: GTA5/images/00244.png
#  inflated: GTA5/images/00245.png
#  inflated: GTA5/images/00246.png
#  inflated: GTA5/images/00247.png
#  inflated: GTA5/images/00248.png
#  inflated: GTA5/images/00249.png
#  inflated: GTA5/images/00250.png
#  inflated: GTA5/images/00251.png
#  inflated: GTA5/images/00252.png
#  inflated: GTA5/images/00253.png
#  inflated: GTA5/images/00254.png
#  inflated: GTA5/images/00255.png
#  inflated: GTA5/images/00256.png
#  inflated: GTA5/images/00257.png
#  inflated: GTA5/images/00258.png
#  inflated: GTA5/images/00259.png
#  inflated: GTA5/images/00260.png
#  inflated: GTA5/images/00261.png
#  inflated: GTA5/images/00262.png
#  inflated: GTA5/images/00263.png
#  inflated: GTA5/images/00264.png
#  inflated: GTA5/images/00265.png
#  inflated: GTA5/images/00266.png
#  inflated: GTA5/images/00267.png
#  inflated: GTA5/images/00268.png
#  inflated: GTA5/images/00269.png
#  inflated: GTA5/images/00270.png
#  inflated: GTA5/images/00271.png
#  inflated: GTA5/images/00272.png
#  inflated: GTA5/images/00273.png
#  inflated: GTA5/images/00274.png
#  inflated: GTA5/images/00275.png
#  inflated: GTA5/images/00276.png
#  inflated: GTA5/images/00277.png
#  inflated: GTA5/images/00278.png
#  inflated: GTA5/images/00279.png
#  inflated: GTA5/images/00280.png
#  inflated: GTA5/images/00281.png
#  inflated: GTA5/images/00282.png
#  inflated: GTA5/images/00283.png
#  inflated: GTA5/images/00284.png
#  inflated: GTA5/images/00285.png
#  inflated: GTA5/images/00286.png
#  inflated: GTA5/images/00287.png
#  inflated: GTA5/images/00288.png
#  inflated: GTA5/images/00289.png
#  inflated: GTA5/images/00290.png
#  inflated: GTA5/images/00291.png
#  inflated: GTA5/images/00292.png
#  inflated: GTA5/images/00293.png
#  inflated: GTA5/images/00294.png
#  inflated: GTA5/images/00295.png
#  inflated: GTA5/images/00296.png
#  inflated: GTA5/images/00297.png
#  inflated: GTA5/images/00298.png
#  inflated: GTA5/images/00299.png
#  inflated: GTA5/images/00300.png
#  inflated: GTA5/images/00301.png
#  inflated: GTA5/images/00302.png
#  inflated: GTA5/images/00303.png
#  inflated: GTA5/images/00304.png
#  inflated: GTA5/images/00305.png
#  inflated: GTA5/images/00306.png
#  inflated: GTA5/images/00307.png
#  inflated: GTA5/images/00308.png
#  inflated: GTA5/images/00309.png
#  inflated: GTA5/images/00310.png
#  inflated: GTA5/images/00311.png
#  inflated: GTA5/images/00312.png
#  inflated: GTA5/images/00313.png
#  inflated: GTA5/images/00314.png
#  inflated: GTA5/images/00315.png
#  inflated: GTA5/images/00316.png
#  inflated: GTA5/images/00317.png
#  inflated: GTA5/images/00318.png
#  inflated: GTA5/images/00319.png
#  inflated: GTA5/images/00320.png
#  inflated: GTA5/images/00321.png
#  inflated: GTA5/images/00322.png
#  inflated: GTA5/images/00323.png
#  inflated: GTA5/images/00324.png
#  inflated: GTA5/images/00325.png
#  inflated: GTA5/images/00326.png
#  inflated: GTA5/images/00327.png
#  inflated: GTA5/images/00328.png
#  inflated: GTA5/images/00329.png
#  inflated: GTA5/images/00330.png
#  inflated: GTA5/images/00331.png
#  inflated: GTA5/images/00332.png
#  inflated: GTA5/images/00333.png
#  inflated: GTA5/images/00334.png
#  inflated: GTA5/images/00335.png
#  inflated: GTA5/images/00336.png
#  inflated: GTA5/images/00337.png
#  inflated: GTA5/images/00338.png
#  inflated: GTA5/images/00339.png
#  inflated: GTA5/images/00340.png
#  inflated: GTA5/images/00341.png
#  inflated: GTA5/images/00342.png
#  inflated: GTA5/images/00343.png
#  inflated: GTA5/images/00344.png
#  inflated: GTA5/images/00345.png
#  inflated: GTA5/images/00346.png
#  inflated: GTA5/images/00347.png
#  inflated: GTA5/images/00348.png
#  inflated: GTA5/images/00349.png
#  inflated: GTA5/images/00350.png
#  inflated: GTA5/images/00351.png
#  inflated: GTA5/images/00352.png
#  inflated: GTA5/images/00353.png
#  inflated: GTA5/images/00354.png
#  inflated: GTA5/images/00355.png
#  inflated: GTA5/images/00356.png
#  inflated: GTA5/images/00357.png
#  inflated: GTA5/images/00358.png
#  inflated: GTA5/images/00359.png
#  inflated: GTA5/images/00360.png
#  inflated: GTA5/images/00361.png
#  inflated: GTA5/images/00362.png
#  inflated: GTA5/images/00363.png
#  inflated: GTA5/images/00364.png
#  inflated: GTA5/images/00365.png
#  inflated: GTA5/images/00366.png
#  inflated: GTA5/images/00367.png
#  inflated: GTA5/images/00368.png
#  inflated: GTA5/images/00369.png
#  inflated: GTA5/images/00370.png
#  inflated: GTA5/images/00371.png
#  inflated: GTA5/images/00372.png
#  inflated: GTA5/images/00373.png
#  inflated: GTA5/images/00374.png
#  inflated: GTA5/images/00375.png
#  inflated: GTA5/images/00376.png
#  inflated: GTA5/images/00377.png
#  inflated: GTA5/images/00378.png
#  inflated: GTA5/images/00379.png
#  inflated: GTA5/images/00380.png
#  inflated: GTA5/images/00381.png
#  inflated: GTA5/images/00382.png
#  inflated: GTA5/images/00383.png
#  inflated: GTA5/images/00384.png
#  inflated: GTA5/images/00385.png
#  inflated: GTA5/images/00386.png
#  inflated: GTA5/images/00387.png
#  inflated: GTA5/images/00388.png
#  inflated: GTA5/images/00389.png
#  inflated: GTA5/images/00390.png
#  inflated: GTA5/images/00391.png
#  inflated: GTA5/images/00392.png
#  inflated: GTA5/images/00393.png
#  inflated: GTA5/images/00394.png
#  inflated: GTA5/images/00395.png
#  inflated: GTA5/images/00396.png
#  inflated: GTA5/images/00397.png
#  inflated: GTA5/images/00398.png
#  inflated: GTA5/images/00399.png
#  inflated: GTA5/images/00400.png
#  inflated: GTA5/images/00401.png
#  inflated: GTA5/images/00402.png
#  inflated: GTA5/images/00403.png
#  inflated: GTA5/images/00404.png
#  inflated: GTA5/images/00405.png
#  inflated: GTA5/images/00406.png
#  inflated: GTA5/images/00407.png
#  inflated: GTA5/images/00408.png
#  inflated: GTA5/images/00409.png
#  inflated: GTA5/images/00410.png
#  inflated: GTA5/images/00411.png
#  inflated: GTA5/images/00412.png
#  inflated: GTA5/images/00413.png
#  inflated: GTA5/images/00414.png
#  inflated: GTA5/images/00415.png
#  inflated: GTA5/images/00416.png
#  inflated: GTA5/images/00417.png
#  inflated: GTA5/images/00418.png
#  inflated: GTA5/images/00419.png
#  inflated: GTA5/images/00420.png
#  inflated: GTA5/images/00421.png
#  inflated: GTA5/images/00422.png
#  inflated: GTA5/images/00423.png
#  inflated: GTA5/images/00424.png
#  inflated: GTA5/images/00425.png
#  inflated: GTA5/images/00426.png
#  inflated: GTA5/images/00427.png
#  inflated: GTA5/images/00428.png
#  inflated: GTA5/images/00429.png
#  inflated: GTA5/images/00430.png
#  inflated: GTA5/images/00431.png
#  inflated: GTA5/images/00432.png
#  inflated: GTA5/images/00433.png
#  inflated: GTA5/images/00434.png
#  inflated: GTA5/images/00435.png
#  inflated: GTA5/images/00436.png
#  inflated: GTA5/images/00437.png
#  inflated: GTA5/images/00438.png
#  inflated: GTA5/images/00439.png
#  inflated: GTA5/images/00440.png
#  inflated: GTA5/images/00441.png
#  inflated: GTA5/images/00442.png
#  inflated: GTA5/images/00443.png
#  inflated: GTA5/images/00444.png
#  inflated: GTA5/images/00445.png
#  inflated: GTA5/images/00446.png
#  inflated: GTA5/images/00447.png
#  inflated: GTA5/images/00448.png
#  inflated: GTA5/images/00449.png
#  inflated: GTA5/images/00450.png
#  inflated: GTA5/images/00451.png
#  inflated: GTA5/images/00452.png
#  inflated: GTA5/images/00453.png
#  inflated: GTA5/images/00454.png
#  inflated: GTA5/images/00455.png
#  inflated: GTA5/images/00456.png
#  inflated: GTA5/images/00457.png
#  inflated: GTA5/images/00458.png
#  inflated: GTA5/images/00459.png
#  inflated: GTA5/images/00460.png
#  inflated: GTA5/images/00461.png
#  inflated: GTA5/images/00462.png
#  inflated: GTA5/images/00463.png
#  inflated: GTA5/images/00464.png
#  inflated: GTA5/images/00465.png
#  inflated: GTA5/images/00466.png
#  inflated: GTA5/images/00467.png
#  inflated: GTA5/images/00468.png
#  inflated: GTA5/images/00469.png
#  inflated: GTA5/images/00470.png
#  inflated: GTA5/images/00471.png
#  inflated: GTA5/images/00472.png
#  inflated: GTA5/images/00473.png
#  inflated: GTA5/images/00474.png
#  inflated: GTA5/images/00475.png
#  inflated: GTA5/images/00476.png
#  inflated: GTA5/images/00477.png
#  inflated: GTA5/images/00478.png
#  inflated: GTA5/images/00479.png
#  inflated: GTA5/images/00480.png
#  inflated: GTA5/images/00481.png
#  inflated: GTA5/images/00482.png
#  inflated: GTA5/images/00483.png
#  inflated: GTA5/images/00484.png
#  inflated: GTA5/images/00485.png
#  inflated: GTA5/images/00486.png
#  inflated: GTA5/images/00487.png
#  inflated: GTA5/images/00488.png
#  inflated: GTA5/images/00489.png
#  inflated: GTA5/images/00490.png
#  inflated: GTA5/images/00491.png
#  inflated: GTA5/images/00492.png
#  inflated: GTA5/images/00493.png
#  inflated: GTA5/images/00494.png
#  inflated: GTA5/images/00495.png
#  inflated: GTA5/images/00496.png
#  inflated: GTA5/images/00497.png
#  inflated: GTA5/images/00498.png
#  inflated: GTA5/images/00499.png
#  inflated: GTA5/images/00500.png
#  inflated: GTA5/images/00501.png
#  inflated: GTA5/images/00502.png
#  inflated: GTA5/images/00503.png
#  inflated: GTA5/images/00504.png
#  inflated: GTA5/images/00505.png
#  inflated: GTA5/images/00506.png
#  inflated: GTA5/images/00507.png
#  inflated: GTA5/images/00508.png
#  inflated: GTA5/images/00509.png
#  inflated: GTA5/images/00510.png
#  inflated: GTA5/images/00511.png
#  inflated: GTA5/images/00512.png
#  inflated: GTA5/images/00513.png
#  inflated: GTA5/images/00514.png
#  inflated: GTA5/images/00515.png
#  inflated: GTA5/images/00516.png
#  inflated: GTA5/images/00517.png
#  inflated: GTA5/images/00518.png
#  inflated: GTA5/images/00519.png
#  inflated: GTA5/images/00520.png
#  inflated: GTA5/images/00521.png
#  inflated: GTA5/images/00522.png
#  inflated: GTA5/images/00523.png
#  inflated: GTA5/images/00524.png
#  inflated: GTA5/images/00525.png
#  inflated: GTA5/images/00526.png
#  inflated: GTA5/images/00527.png
#  inflated: GTA5/images/00528.png
#  inflated: GTA5/images/00529.png
#  inflated: GTA5/images/00530.png
#  inflated: GTA5/images/00531.png
#  inflated: GTA5/images/00532.png
#  inflated: GTA5/images/00533.png
#  inflated: GTA5/images/00534.png
#  inflated: GTA5/images/00535.png
#  inflated: GTA5/images/00536.png
#  inflated: GTA5/images/00537.png
#  inflated: GTA5/images/00538.png
#  inflated: GTA5/images/00539.png
#  inflated: GTA5/images/00540.png
#  inflated: GTA5/images/00541.png
#  inflated: GTA5/images/00542.png
#  inflated: GTA5/images/00543.png
#  inflated: GTA5/images/00544.png
#  inflated: GTA5/images/00545.png
#  inflated: GTA5/images/00546.png
#  inflated: GTA5/images/00547.png
#  inflated: GTA5/images/00548.png
#  inflated: GTA5/images/00549.png
#  inflated: GTA5/images/00550.png
#  inflated: GTA5/images/00551.png
#  inflated: GTA5/images/00552.png
#  inflated: GTA5/images/00553.png
#  inflated: GTA5/images/00554.png
#  inflated: GTA5/images/00555.png
#  inflated: GTA5/images/00556.png
#  inflated: GTA5/images/00557.png
#  inflated: GTA5/images/00558.png
#  inflated: GTA5/images/00559.png
#  inflated: GTA5/images/00560.png
#  inflated: GTA5/images/00561.png
#  inflated: GTA5/images/00562.png
#  inflated: GTA5/images/00563.png
#  inflated: GTA5/images/00564.png
#  inflated: GTA5/images/00565.png
#  inflated: GTA5/images/00566.png
#  inflated: GTA5/images/00567.png
#  inflated: GTA5/images/00568.png
#  inflated: GTA5/images/00569.png
#  inflated: GTA5/images/00570.png
#  inflated: GTA5/images/00571.png
#  inflated: GTA5/images/00572.png
#  inflated: GTA5/images/00573.png
#  inflated: GTA5/images/00574.png
#  inflated: GTA5/images/00575.png
#  inflated: GTA5/images/00576.png
#  inflated: GTA5/images/00577.png
#  inflated: GTA5/images/00578.png
#  inflated: GTA5/images/00579.png
#  inflated: GTA5/images/00580.png
#  inflated: GTA5/images/00581.png
#  inflated: GTA5/images/00582.png
#  inflated: GTA5/images/00583.png
#  inflated: GTA5/images/00584.png
#  inflated: GTA5/images/00585.png
#  inflated: GTA5/images/00586.png
#  inflated: GTA5/images/00587.png
#  inflated: GTA5/images/00588.png
#  inflated: GTA5/images/00589.png
#  inflated: GTA5/images/00590.png
#  inflated: GTA5/images/00591.png
#  inflated: GTA5/images/00592.png
#  inflated: GTA5/images/00593.png
#  inflated: GTA5/images/00594.png
#  inflated: GTA5/images/00595.png
#  inflated: GTA5/images/00596.png
#  inflated: GTA5/images/00597.png
#  inflated: GTA5/images/00598.png
#  inflated: GTA5/images/00599.png
#  inflated: GTA5/images/00600.png
#  inflated: GTA5/images/00601.png
#  inflated: GTA5/images/00602.png
#  inflated: GTA5/images/00603.png
#  inflated: GTA5/images/00604.png
#  inflated: GTA5/images/00605.png
#  inflated: GTA5/images/00606.png
#  inflated: GTA5/images/00607.png
#  inflated: GTA5/images/00608.png
#  inflated: GTA5/images/00609.png
#  inflated: GTA5/images/00610.png
#  inflated: GTA5/images/00611.png
#  inflated: GTA5/images/00612.png
#  inflated: GTA5/images/00613.png
#  inflated: GTA5/images/00614.png
#  inflated: GTA5/images/00615.png
#  inflated: GTA5/images/00616.png
#  inflated: GTA5/images/00617.png
#  inflated: GTA5/images/00618.png
#  inflated: GTA5/images/00619.png
#  inflated: GTA5/images/00620.png
#  inflated: GTA5/images/00621.png
#  inflated: GTA5/images/00622.png
#  inflated: GTA5/images/00623.png
#  inflated: GTA5/images/00624.png
#  inflated: GTA5/images/00625.png
#  inflated: GTA5/images/00626.png
#  inflated: GTA5/images/00627.png
#  inflated: GTA5/images/00628.png
#  inflated: GTA5/images/00629.png
#  inflated: GTA5/images/00630.png
#  inflated: GTA5/images/00631.png
#  inflated: GTA5/images/00632.png
#  inflated: GTA5/images/00633.png
#  inflated: GTA5/images/00634.png
#  inflated: GTA5/images/00635.png
#  inflated: GTA5/images/00636.png
#  inflated: GTA5/images/00637.png
#  inflated: GTA5/images/00638.png
#  inflated: GTA5/images/00639.png
#  inflated: GTA5/images/00640.png
#  inflated: GTA5/images/00641.png
#  inflated: GTA5/images/00642.png
#  inflated: GTA5/images/00643.png
#  inflated: GTA5/images/00644.png
#  inflated: GTA5/images/00645.png
#  inflated: GTA5/images/00646.png
#  inflated: GTA5/images/00647.png
#  inflated: GTA5/images/00648.png
#  inflated: GTA5/images/00649.png
#  inflated: GTA5/images/00650.png
#  inflated: GTA5/images/00651.png
#  inflated: GTA5/images/00652.png
#  inflated: GTA5/images/00653.png
#  inflated: GTA5/images/00654.png
#  inflated: GTA5/images/00655.png
#  inflated: GTA5/images/00656.png
#  inflated: GTA5/images/00657.png
#  inflated: GTA5/images/00658.png
#  inflated: GTA5/images/00659.png
#  inflated: GTA5/images/00660.png
#  inflated: GTA5/images/00661.png
#  inflated: GTA5/images/00662.png
#  inflated: GTA5/images/00663.png
#  inflated: GTA5/images/00664.png
#  inflated: GTA5/images/00665.png
#  inflated: GTA5/images/00666.png
#  inflated: GTA5/images/00667.png
#  inflated: GTA5/images/00668.png
#  inflated: GTA5/images/00669.png
#  inflated: GTA5/images/00670.png
#  inflated: GTA5/images/00671.png
#  inflated: GTA5/images/00672.png
#  inflated: GTA5/images/00673.png
#  inflated: GTA5/images/00674.png
#  inflated: GTA5/images/00675.png
#  inflated: GTA5/images/00676.png
#  inflated: GTA5/images/00677.png
#  inflated: GTA5/images/00678.png
#  inflated: GTA5/images/00679.png
#  inflated: GTA5/images/00680.png
#  inflated: GTA5/images/00681.png
#  inflated: GTA5/images/00682.png
#  inflated: GTA5/images/00683.png
#  inflated: GTA5/images/00684.png
#  inflated: GTA5/images/00685.png
#  inflated: GTA5/images/00686.png
#  inflated: GTA5/images/00687.png
#  inflated: GTA5/images/00688.png
#  inflated: GTA5/images/00689.png
#  inflated: GTA5/images/00690.png
#  inflated: GTA5/images/00691.png
#  inflated: GTA5/images/00692.png
#  inflated: GTA5/images/00693.png
#  inflated: GTA5/images/00694.png
#  inflated: GTA5/images/00695.png
#  inflated: GTA5/images/00696.png
#  inflated: GTA5/images/00697.png
#  inflated: GTA5/images/00698.png
#  inflated: GTA5/images/00699.png
#  inflated: GTA5/images/00700.png
#  inflated: GTA5/images/00701.png
#  inflated: GTA5/images/00702.png
#  inflated: GTA5/images/00703.png
#  inflated: GTA5/images/00704.png
#  inflated: GTA5/images/00705.png
#  inflated: GTA5/images/00706.png
#  inflated: GTA5/images/00707.png
#  inflated: GTA5/images/00708.png
#  inflated: GTA5/images/00709.png
#  inflated: GTA5/images/00710.png
#  inflated: GTA5/images/00711.png
#  inflated: GTA5/images/00712.png
#  inflated: GTA5/images/00713.png
#  inflated: GTA5/images/00714.png
#  inflated: GTA5/images/00715.png
#  inflated: GTA5/images/00716.png
#  inflated: GTA5/images/00717.png
#  inflated: GTA5/images/00718.png
#  inflated: GTA5/images/00719.png
#  inflated: GTA5/images/00720.png
#  inflated: GTA5/images/00721.png
#  inflated: GTA5/images/00722.png
#  inflated: GTA5/images/00723.png
#  inflated: GTA5/images/00724.png
#  inflated: GTA5/images/00725.png
#  inflated: GTA5/images/00726.png
#  inflated: GTA5/images/00727.png
#  inflated: GTA5/images/00728.png
#  inflated: GTA5/images/00729.png
#  inflated: GTA5/images/00730.png
#  inflated: GTA5/images/00731.png
#  inflated: GTA5/images/00732.png
#  inflated: GTA5/images/00733.png
#  inflated: GTA5/images/00734.png
#  inflated: GTA5/images/00735.png
#  inflated: GTA5/images/00736.png
#  inflated: GTA5/images/00737.png
#  inflated: GTA5/images/00738.png
#  inflated: GTA5/images/00739.png
#  inflated: GTA5/images/00740.png
#  inflated: GTA5/images/00741.png
#  inflated: GTA5/images/00742.png
#  inflated: GTA5/images/00743.png
#  inflated: GTA5/images/00744.png
#  inflated: GTA5/images/00745.png
#  inflated: GTA5/images/00746.png
#  inflated: GTA5/images/00747.png
#  inflated: GTA5/images/00748.png
#  inflated: GTA5/images/00749.png
#  inflated: GTA5/images/00750.png
#  inflated: GTA5/images/00751.png
#  inflated: GTA5/images/00752.png
#  inflated: GTA5/images/00753.png
#  inflated: GTA5/images/00754.png
#  inflated: GTA5/images/00755.png
#  inflated: GTA5/images/00756.png
#  inflated: GTA5/images/00757.png
#  inflated: GTA5/images/00758.png
#  inflated: GTA5/images/00759.png
#  inflated: GTA5/images/00760.png
#  inflated: GTA5/images/00761.png
#  inflated: GTA5/images/00762.png
#  inflated: GTA5/images/00763.png
#  inflated: GTA5/images/00764.png
#  inflated: GTA5/images/00765.png
#  inflated: GTA5/images/00766.png
#  inflated: GTA5/images/00767.png
#  inflated: GTA5/images/00768.png
#  inflated: GTA5/images/00769.png
#  inflated: GTA5/images/00770.png
#  inflated: GTA5/images/00771.png
#  inflated: GTA5/images/00772.png
#  inflated: GTA5/images/00773.png
#  inflated: GTA5/images/00774.png
#  inflated: GTA5/images/00775.png
#  inflated: GTA5/images/00776.png
#  inflated: GTA5/images/00777.png
#  inflated: GTA5/images/00778.png
#  inflated: GTA5/images/00779.png
#  inflated: GTA5/images/00780.png
#  inflated: GTA5/images/00781.png
#  inflated: GTA5/images/00782.png
#  inflated: GTA5/images/00783.png
#  inflated: GTA5/images/00784.png
#  inflated: GTA5/images/00785.png
#  inflated: GTA5/images/00786.png
#  inflated: GTA5/images/00787.png
#  inflated: GTA5/images/00788.png
#  inflated: GTA5/images/00789.png
#  inflated: GTA5/images/00790.png
#  inflated: GTA5/images/00791.png
#  inflated: GTA5/images/00792.png
#  inflated: GTA5/images/00793.png
#  inflated: GTA5/images/00794.png
#  inflated: GTA5/images/00795.png
#  inflated: GTA5/images/00796.png
#  inflated: GTA5/images/00797.png
#  inflated: GTA5/images/00798.png
#  inflated: GTA5/images/00799.png
#  inflated: GTA5/images/00800.png
#  inflated: GTA5/images/00801.png
#  inflated: GTA5/images/00802.png
#  inflated: GTA5/images/00803.png
#  inflated: GTA5/images/00804.png
#  inflated: GTA5/images/00805.png
#  inflated: GTA5/images/00806.png
#  inflated: GTA5/images/00807.png
#  inflated: GTA5/images/00808.png
#  inflated: GTA5/images/00809.png
#  inflated: GTA5/images/00810.png
#  inflated: GTA5/images/00811.png
#  inflated: GTA5/images/00812.png
#  inflated: GTA5/images/00813.png
#  inflated: GTA5/images/00814.png
#  inflated: GTA5/images/00815.png
#  inflated: GTA5/images/00816.png
#  inflated: GTA5/images/00817.png
#  inflated: GTA5/images/00818.png
#  inflated: GTA5/images/00819.png
#  inflated: GTA5/images/00820.png
#  inflated: GTA5/images/00821.png
#  inflated: GTA5/images/00822.png
#  inflated: GTA5/images/00823.png
#  inflated: GTA5/images/00824.png
#  inflated: GTA5/images/00825.png
#  inflated: GTA5/images/00826.png
#  inflated: GTA5/images/00827.png
#  inflated: GTA5/images/00828.png
#  inflated: GTA5/images/00829.png
#  inflated: GTA5/images/00830.png
#  inflated: GTA5/images/00831.png
#  inflated: GTA5/images/00832.png
#  inflated: GTA5/images/00833.png
#  inflated: GTA5/images/00834.png
#  inflated: GTA5/images/00835.png
#  inflated: GTA5/images/00836.png
#  inflated: GTA5/images/00837.png
#  inflated: GTA5/images/00838.png
#  inflated: GTA5/images/00839.png
#  inflated: GTA5/images/00840.png
#  inflated: GTA5/images/00841.png
#  inflated: GTA5/images/00842.png
#  inflated: GTA5/images/00843.png
#  inflated: GTA5/images/00844.png
#  inflated: GTA5/images/00845.png
#  inflated: GTA5/images/00846.png
#  inflated: GTA5/images/00847.png
#  inflated: GTA5/images/00848.png
#  inflated: GTA5/images/00849.png
#  inflated: GTA5/images/00850.png
#  inflated: GTA5/images/00851.png
#  inflated: GTA5/images/00852.png
#  inflated: GTA5/images/00853.png
#  inflated: GTA5/images/00854.png
#  inflated: GTA5/images/00855.png
#  inflated: GTA5/images/00856.png
#  inflated: GTA5/images/00857.png
#  inflated: GTA5/images/00858.png
#  inflated: GTA5/images/00859.png
#  inflated: GTA5/images/00860.png
#  inflated: GTA5/images/00861.png
#  inflated: GTA5/images/00862.png
#  inflated: GTA5/images/00863.png
#  inflated: GTA5/images/00864.png
#  inflated: GTA5/images/00865.png
#  inflated: GTA5/images/00866.png
#  inflated: GTA5/images/00867.png
#  inflated: GTA5/images/00868.png
#  inflated: GTA5/images/00869.png
#  inflated: GTA5/images/00870.png
#  inflated: GTA5/images/00871.png
#  inflated: GTA5/images/00872.png
#  inflated: GTA5/images/00873.png
#  inflated: GTA5/images/00874.png
#  inflated: GTA5/images/00875.png
#  inflated: GTA5/images/00876.png
#  inflated: GTA5/images/00877.png
#  inflated: GTA5/images/00878.png
#  inflated: GTA5/images/00879.png
#  inflated: GTA5/images/00880.png
#  inflated: GTA5/images/00881.png
#  inflated: GTA5/images/00882.png
#  inflated: GTA5/images/00883.png
#  inflated: GTA5/images/00884.png
#  inflated: GTA5/images/00885.png
#  inflated: GTA5/images/00886.png
#  inflated: GTA5/images/00887.png
#  inflated: GTA5/images/00888.png
#  inflated: GTA5/images/00889.png
#  inflated: GTA5/images/00890.png
#  inflated: GTA5/images/00891.png
#  inflated: GTA5/images/00892.png
#  inflated: GTA5/images/00893.png
#  inflated: GTA5/images/00894.png
#  inflated: GTA5/images/00895.png
#  inflated: GTA5/images/00896.png
#  inflated: GTA5/images/00897.png
#  inflated: GTA5/images/00898.png
#  inflated: GTA5/images/00899.png
#  inflated: GTA5/images/00900.png
#  inflated: GTA5/images/00901.png
#  inflated: GTA5/images/00902.png
#  inflated: GTA5/images/00903.png
#  inflated: GTA5/images/00904.png
#  inflated: GTA5/images/00905.png
#  inflated: GTA5/images/00906.png
#  inflated: GTA5/images/00907.png
#  inflated: GTA5/images/00908.png
#  inflated: GTA5/images/00909.png
#  inflated: GTA5/images/00910.png
#  inflated: GTA5/images/00911.png
#  inflated: GTA5/images/00912.png
#  inflated: GTA5/images/00913.png
#  inflated: GTA5/images/00914.png
#  inflated: GTA5/images/00915.png
#  inflated: GTA5/images/00916.png
#  inflated: GTA5/images/00917.png
#  inflated: GTA5/images/00918.png
#  inflated: GTA5/images/00919.png
#  inflated: GTA5/images/00920.png
#  inflated: GTA5/images/00921.png
#  inflated: GTA5/images/00922.png
#  inflated: GTA5/images/00923.png
#  inflated: GTA5/images/00924.png
#  inflated: GTA5/images/00925.png
#  inflated: GTA5/images/00926.png
#  inflated: GTA5/images/00927.png
#  inflated: GTA5/images/00928.png
#  inflated: GTA5/images/00929.png
#  inflated: GTA5/images/00930.png
#  inflated: GTA5/images/00931.png
#  inflated: GTA5/images/00932.png
#  inflated: GTA5/images/00933.png
#  inflated: GTA5/images/00934.png
#  inflated: GTA5/images/00935.png
#  inflated: GTA5/images/00936.png
#  inflated: GTA5/images/00937.png
#  inflated: GTA5/images/00938.png
#  inflated: GTA5/images/00939.png
#  inflated: GTA5/images/00940.png
#  inflated: GTA5/images/00941.png
#  inflated: GTA5/images/00942.png
#  inflated: GTA5/images/00943.png
#  inflated: GTA5/images/00944.png
#  inflated: GTA5/images/00945.png
#  inflated: GTA5/images/00946.png
#  inflated: GTA5/images/00947.png
#  inflated: GTA5/images/00948.png
#  inflated: GTA5/images/00949.png
#  inflated: GTA5/images/00950.png
#  inflated: GTA5/images/00951.png
#  inflated: GTA5/images/00952.png
#  inflated: GTA5/images/00953.png
#  inflated: GTA5/images/00954.png
#  inflated: GTA5/images/00955.png
#  inflated: GTA5/images/00956.png
#  inflated: GTA5/images/00957.png
#  inflated: GTA5/images/00958.png
#  inflated: GTA5/images/00959.png
#  inflated: GTA5/images/00960.png
#  inflated: GTA5/images/00961.png
#  inflated: GTA5/images/00962.png
#  inflated: GTA5/images/00963.png
#  inflated: GTA5/images/00964.png
#  inflated: GTA5/images/00965.png
#  inflated: GTA5/images/00966.png
#  inflated: GTA5/images/00967.png
#  inflated: GTA5/images/00968.png
#  inflated: GTA5/images/00969.png
#  inflated: GTA5/images/00970.png
#  inflated: GTA5/images/00971.png
#  inflated: GTA5/images/00972.png
#  inflated: GTA5/images/00973.png
#  inflated: GTA5/images/00974.png
#  inflated: GTA5/images/00975.png
#  inflated: GTA5/images/00976.png
#  inflated: GTA5/images/00977.png
#  inflated: GTA5/images/00978.png
#  inflated: GTA5/images/00979.png
#  inflated: GTA5/images/00980.png
#  inflated: GTA5/images/00981.png
#  inflated: GTA5/images/00982.png
#  inflated: GTA5/images/00983.png
#  inflated: GTA5/images/00984.png
#  inflated: GTA5/images/00985.png
#  inflated: GTA5/images/00986.png
#  inflated: GTA5/images/00987.png
#  inflated: GTA5/images/00988.png
#  inflated: GTA5/images/00989.png
#  inflated: GTA5/images/00990.png
#  inflated: GTA5/images/00991.png
#  inflated: GTA5/images/00992.png
#  inflated: GTA5/images/00993.png
#  inflated: GTA5/images/00994.png
#  inflated: GTA5/images/00995.png
#  inflated: GTA5/images/00996.png
#  inflated: GTA5/images/00997.png
#  inflated: GTA5/images/00998.png
#  inflated: GTA5/images/00999.png
#  inflated: GTA5/images/01000.png
#  inflated: GTA5/images/01001.png
#  inflated: GTA5/images/01002.png
#  inflated: GTA5/images/01003.png
#  inflated: GTA5/images/01004.png
#  inflated: GTA5/images/01005.png
#  inflated: GTA5/images/01006.png
#  inflated: GTA5/images/01007.png
#  inflated: GTA5/images/01008.png
#  inflated: GTA5/images/01009.png
#  inflated: GTA5/images/01010.png
#  inflated: GTA5/images/01011.png
#  inflated: GTA5/images/01012.png
#  inflated: GTA5/images/01013.png
#  inflated: GTA5/images/01014.png
#  inflated: GTA5/images/01015.png
#  inflated: GTA5/images/01016.png
#  inflated: GTA5/images/01017.png
#  inflated: GTA5/images/01018.png
#  inflated: GTA5/images/01019.png
#  inflated: GTA5/images/01020.png
#  inflated: GTA5/images/01021.png
#  inflated: GTA5/images/01022.png
#  inflated: GTA5/images/01023.png
#  inflated: GTA5/images/01024.png
#  inflated: GTA5/images/01025.png
#  inflated: GTA5/images/01026.png
#  inflated: GTA5/images/01027.png
#  inflated: GTA5/images/01028.png
#  inflated: GTA5/images/01029.png
#  inflated: GTA5/images/01030.png
#  inflated: GTA5/images/01031.png
#  inflated: GTA5/images/01032.png
#  inflated: GTA5/images/01033.png
#  inflated: GTA5/images/01034.png
#  inflated: GTA5/images/01035.png
#  inflated: GTA5/images/01036.png
#  inflated: GTA5/images/01037.png
#  inflated: GTA5/images/01038.png
#  inflated: GTA5/images/01039.png
#  inflated: GTA5/images/01040.png
#  inflated: GTA5/images/01041.png
#  inflated: GTA5/images/01042.png
#  inflated: GTA5/images/01043.png
#  inflated: GTA5/images/01044.png
#  inflated: GTA5/images/01045.png
#  inflated: GTA5/images/01046.png
#  inflated: GTA5/images/01047.png
#  inflated: GTA5/images/01048.png
#  inflated: GTA5/images/01049.png
#  inflated: GTA5/images/01050.png
#  inflated: GTA5/images/01051.png
#  inflated: GTA5/images/01052.png
#  inflated: GTA5/images/01053.png
#  inflated: GTA5/images/01054.png
#  inflated: GTA5/images/01055.png
#  inflated: GTA5/images/01056.png
#  inflated: GTA5/images/01057.png
#  inflated: GTA5/images/01058.png
#  inflated: GTA5/images/01059.png
#  inflated: GTA5/images/01060.png
#  inflated: GTA5/images/01061.png
#  inflated: GTA5/images/01062.png
#  inflated: GTA5/images/01063.png
#  inflated: GTA5/images/01064.png
#  inflated: GTA5/images/01065.png
#  inflated: GTA5/images/01066.png
#  inflated: GTA5/images/01067.png
#  inflated: GTA5/images/01068.png
#  inflated: GTA5/images/01069.png
#  inflated: GTA5/images/01070.png
#  inflated: GTA5/images/01071.png
#  inflated: GTA5/images/01072.png
#  inflated: GTA5/images/01073.png
#  inflated: GTA5/images/01074.png
#  inflated: GTA5/images/01075.png
#  inflated: GTA5/images/01076.png
#  inflated: GTA5/images/01077.png
#  inflated: GTA5/images/01078.png
#  inflated: GTA5/images/01079.png
#  inflated: GTA5/images/01080.png
#  inflated: GTA5/images/01081.png
#  inflated: GTA5/images/01082.png
#  inflated: GTA5/images/01083.png
#  inflated: GTA5/images/01084.png
#  inflated: GTA5/images/01085.png
#  inflated: GTA5/images/01086.png
#  inflated: GTA5/images/01087.png
#  inflated: GTA5/images/01088.png
#  inflated: GTA5/images/01089.png
#  inflated: GTA5/images/01090.png
#  inflated: GTA5/images/01091.png
#  inflated: GTA5/images/01092.png
#  inflated: GTA5/images/01093.png
#  inflated: GTA5/images/01094.png
#  inflated: GTA5/images/01095.png
#  inflated: GTA5/images/01096.png
#  inflated: GTA5/images/01097.png
#  inflated: GTA5/images/01098.png
#  inflated: GTA5/images/01099.png
#  inflated: GTA5/images/01100.png
#  inflated: GTA5/images/01101.png
#  inflated: GTA5/images/01102.png
#  inflated: GTA5/images/01103.png
#  inflated: GTA5/images/01104.png
#  inflated: GTA5/images/01105.png
#  inflated: GTA5/images/01106.png
#  inflated: GTA5/images/01107.png
#  inflated: GTA5/images/01108.png
#  inflated: GTA5/images/01109.png
#  inflated: GTA5/images/01110.png
#  inflated: GTA5/images/01111.png
#  inflated: GTA5/images/01112.png
#  inflated: GTA5/images/01113.png
#  inflated: GTA5/images/01114.png
#  inflated: GTA5/images/01115.png
#  inflated: GTA5/images/01116.png
#  inflated: GTA5/images/01117.png
#  inflated: GTA5/images/01118.png
#  inflated: GTA5/images/01119.png
#  inflated: GTA5/images/01120.png
#  inflated: GTA5/images/01121.png
#  inflated: GTA5/images/01122.png
#  inflated: GTA5/images/01123.png
#  inflated: GTA5/images/01124.png
#  inflated: GTA5/images/01125.png
#  inflated: GTA5/images/01126.png
#  inflated: GTA5/images/01127.png
#  inflated: GTA5/images/01128.png
#  inflated: GTA5/images/01129.png
#  inflated: GTA5/images/01130.png
#  inflated: GTA5/images/01131.png
#  inflated: GTA5/images/01132.png
#  inflated: GTA5/images/01133.png
#  inflated: GTA5/images/01134.png
#  inflated: GTA5/images/01135.png
#  inflated: GTA5/images/01136.png
#  inflated: GTA5/images/01137.png
#  inflated: GTA5/images/01138.png
#  inflated: GTA5/images/01139.png
#  inflated: GTA5/images/01140.png
#  inflated: GTA5/images/01141.png
#  inflated: GTA5/images/01142.png
#  inflated: GTA5/images/01143.png
#  inflated: GTA5/images/01144.png
#  inflated: GTA5/images/01145.png
#  inflated: GTA5/images/01146.png
#  inflated: GTA5/images/01147.png
#  inflated: GTA5/images/01148.png
#  inflated: GTA5/images/01149.png
#  inflated: GTA5/images/01150.png
#  inflated: GTA5/images/01151.png
#  inflated: GTA5/images/01152.png
#  inflated: GTA5/images/01153.png
#  inflated: GTA5/images/01154.png
#  inflated: GTA5/images/01155.png
#  inflated: GTA5/images/01156.png
#  inflated: GTA5/images/01157.png
#  inflated: GTA5/images/01158.png
#  inflated: GTA5/images/01159.png
#  inflated: GTA5/images/01160.png
#  inflated: GTA5/images/01161.png
#  inflated: GTA5/images/01162.png
#  inflated: GTA5/images/01163.png
#  inflated: GTA5/images/01164.png
#  inflated: GTA5/images/01165.png
#  inflated: GTA5/images/01166.png
#  inflated: GTA5/images/01167.png
#  inflated: GTA5/images/01168.png
#  inflated: GTA5/images/01169.png
#  inflated: GTA5/images/01170.png
#  inflated: GTA5/images/01171.png
#  inflated: GTA5/images/01172.png
#  inflated: GTA5/images/01173.png
#  inflated: GTA5/images/01174.png
#  inflated: GTA5/images/01175.png
#  inflated: GTA5/images/01176.png
#  inflated: GTA5/images/01177.png
#  inflated: GTA5/images/01178.png
#  inflated: GTA5/images/01179.png
#  inflated: GTA5/images/01180.png
#  inflated: GTA5/images/01181.png
#  inflated: GTA5/images/01182.png
#  inflated: GTA5/images/01183.png
#  inflated: GTA5/images/01184.png
#  inflated: GTA5/images/01185.png
#  inflated: GTA5/images/01186.png
#  inflated: GTA5/images/01187.png
#  inflated: GTA5/images/01188.png
#  inflated: GTA5/images/01189.png
#  inflated: GTA5/images/01190.png
#  inflated: GTA5/images/01191.png
#  inflated: GTA5/images/01192.png
#  inflated: GTA5/images/01193.png
#  inflated: GTA5/images/01194.png
#  inflated: GTA5/images/01195.png
#  inflated: GTA5/images/01196.png
#  inflated: GTA5/images/01197.png
#  inflated: GTA5/images/01198.png
#  inflated: GTA5/images/01199.png
#  inflated: GTA5/images/01200.png
#  inflated: GTA5/images/01201.png
#  inflated: GTA5/images/01202.png
#  inflated: GTA5/images/01203.png
#  inflated: GTA5/images/01204.png
#  inflated: GTA5/images/01205.png
#  inflated: GTA5/images/01206.png
#  inflated: GTA5/images/01207.png
#  inflated: GTA5/images/01208.png
#  inflated: GTA5/images/01209.png
#  inflated: GTA5/images/01210.png
#  inflated: GTA5/images/01211.png
#  inflated: GTA5/images/01212.png
#  inflated: GTA5/images/01213.png
#  inflated: GTA5/images/01214.png
#  inflated: GTA5/images/01215.png
#  inflated: GTA5/images/01216.png
#  inflated: GTA5/images/01217.png
#  inflated: GTA5/images/01218.png
#  inflated: GTA5/images/01219.png
#  inflated: GTA5/images/01220.png
#  inflated: GTA5/images/01221.png
#  inflated: GTA5/images/01222.png
#  inflated: GTA5/images/01223.png
#  inflated: GTA5/images/01224.png
#  inflated: GTA5/images/01225.png
#  inflated: GTA5/images/01226.png
#  inflated: GTA5/images/01227.png
#  inflated: GTA5/images/01228.png
#  inflated: GTA5/images/01229.png
#  inflated: GTA5/images/01230.png
#  inflated: GTA5/images/01231.png
#  inflated: GTA5/images/01232.png
#  inflated: GTA5/images/01233.png
#  inflated: GTA5/images/01234.png
#  inflated: GTA5/images/01235.png
#  inflated: GTA5/images/01236.png
#  inflated: GTA5/images/01237.png
#  inflated: GTA5/images/01238.png
#  inflated: GTA5/images/01239.png
#  inflated: GTA5/images/01240.png
#  inflated: GTA5/images/01241.png
#  inflated: GTA5/images/01242.png
#  inflated: GTA5/images/01243.png
#  inflated: GTA5/images/01244.png
#  inflated: GTA5/images/01245.png
#  inflated: GTA5/images/01246.png
#  inflated: GTA5/images/01247.png
#  inflated: GTA5/images/01248.png
#  inflated: GTA5/images/01249.png
#  inflated: GTA5/images/01250.png
#  inflated: GTA5/images/01251.png
#  inflated: GTA5/images/01252.png
#  inflated: GTA5/images/01253.png
#  inflated: GTA5/images/01254.png
#  inflated: GTA5/images/01255.png
#  inflated: GTA5/images/01256.png
#  inflated: GTA5/images/01257.png
#  inflated: GTA5/images/01258.png
#  inflated: GTA5/images/01259.png
#  inflated: GTA5/images/01260.png
#  inflated: GTA5/images/01261.png
#  inflated: GTA5/images/01262.png
#  inflated: GTA5/images/01263.png
#  inflated: GTA5/images/01264.png
#  inflated: GTA5/images/01265.png
#  inflated: GTA5/images/01266.png
#  inflated: GTA5/images/01267.png
#  inflated: GTA5/images/01268.png
#  inflated: GTA5/images/01269.png
#  inflated: GTA5/images/01270.png
#  inflated: GTA5/images/01271.png
#  inflated: GTA5/images/01272.png
#  inflated: GTA5/images/01273.png
#  inflated: GTA5/images/01274.png
#  inflated: GTA5/images/01275.png
#  inflated: GTA5/images/01276.png
#  inflated: GTA5/images/01277.png
#  inflated: GTA5/images/01278.png
#  inflated: GTA5/images/01279.png
#  inflated: GTA5/images/01280.png
#  inflated: GTA5/images/01281.png
#  inflated: GTA5/images/01282.png
#  inflated: GTA5/images/01283.png
#  inflated: GTA5/images/01284.png
#  inflated: GTA5/images/01285.png
#  inflated: GTA5/images/01286.png
#  inflated: GTA5/images/01287.png
#  inflated: GTA5/images/01288.png
#  inflated: GTA5/images/01289.png
#  inflated: GTA5/images/01290.png
#  inflated: GTA5/images/01291.png
#  inflated: GTA5/images/01292.png
#  inflated: GTA5/images/01293.png
#  inflated: GTA5/images/01294.png
#  inflated: GTA5/images/01295.png
#  inflated: GTA5/images/01296.png
#  inflated: GTA5/images/01297.png
#  inflated: GTA5/images/01298.png
#  inflated: GTA5/images/01299.png
#  inflated: GTA5/images/01300.png
#  inflated: GTA5/images/01301.png
#  inflated: GTA5/images/01302.png
#  inflated: GTA5/images/01303.png
#  inflated: GTA5/images/01304.png
#  inflated: GTA5/images/01305.png
#  inflated: GTA5/images/01306.png
#  inflated: GTA5/images/01307.png
#  inflated: GTA5/images/01308.png
#  inflated: GTA5/images/01309.png
#  inflated: GTA5/images/01310.png
#  inflated: GTA5/images/01311.png
#  inflated: GTA5/images/01312.png
#  inflated: GTA5/images/01313.png
#  inflated: GTA5/images/01314.png
#  inflated: GTA5/images/01315.png
#  inflated: GTA5/images/01316.png
#  inflated: GTA5/images/01317.png
#  inflated: GTA5/images/01318.png
#  inflated: GTA5/images/01319.png
#  inflated: GTA5/images/01320.png
#  inflated: GTA5/images/01321.png
#  inflated: GTA5/images/01322.png
#  inflated: GTA5/images/01323.png
#  inflated: GTA5/images/01324.png
#  inflated: GTA5/images/01325.png
#  inflated: GTA5/images/01326.png
#  inflated: GTA5/images/01327.png
#  inflated: GTA5/images/01328.png
#  inflated: GTA5/images/01329.png
#  inflated: GTA5/images/01330.png
#  inflated: GTA5/images/01331.png
#  inflated: GTA5/images/01332.png
#  inflated: GTA5/images/01333.png
#  inflated: GTA5/images/01334.png
#  inflated: GTA5/images/01335.png
#  inflated: GTA5/images/01336.png
#  inflated: GTA5/images/01337.png
#  inflated: GTA5/images/01338.png
#  inflated: GTA5/images/01339.png
#  inflated: GTA5/images/01340.png
#  inflated: GTA5/images/01341.png
#  inflated: GTA5/images/01342.png
#  inflated: GTA5/images/01343.png
#  inflated: GTA5/images/01344.png
#  inflated: GTA5/images/01345.png
#  inflated: GTA5/images/01346.png
#  inflated: GTA5/images/01347.png
#  inflated: GTA5/images/01348.png
#  inflated: GTA5/images/01349.png
#  inflated: GTA5/images/01350.png
#  inflated: GTA5/images/01351.png
#  inflated: GTA5/images/01352.png
#  inflated: GTA5/images/01353.png
#  inflated: GTA5/images/01354.png
#  inflated: GTA5/images/01355.png
#  inflated: GTA5/images/01356.png
#  inflated: GTA5/images/01357.png
#  inflated: GTA5/images/01358.png
#  inflated: GTA5/images/01359.png
#  inflated: GTA5/images/01360.png
#  inflated: GTA5/images/01361.png
#  inflated: GTA5/images/01362.png
#  inflated: GTA5/images/01363.png
#  inflated: GTA5/images/01364.png
#  inflated: GTA5/images/01365.png
#  inflated: GTA5/images/01366.png
#  inflated: GTA5/images/01367.png
#  inflated: GTA5/images/01368.png
#  inflated: GTA5/images/01369.png
#  inflated: GTA5/images/01370.png
#  inflated: GTA5/images/01371.png
#  inflated: GTA5/images/01372.png
#  inflated: GTA5/images/01373.png
#  inflated: GTA5/images/01374.png
#  inflated: GTA5/images/01375.png
#  inflated: GTA5/images/01376.png
#  inflated: GTA5/images/01377.png
#  inflated: GTA5/images/01378.png
#  inflated: GTA5/images/01379.png
#  inflated: GTA5/images/01380.png
#  inflated: GTA5/images/01381.png
#  inflated: GTA5/images/01382.png
#  inflated: GTA5/images/01383.png
#  inflated: GTA5/images/01384.png
#  inflated: GTA5/images/01385.png
#  inflated: GTA5/images/01386.png
#  inflated: GTA5/images/01387.png
#  inflated: GTA5/images/01388.png
#  inflated: GTA5/images/01389.png
#  inflated: GTA5/images/01390.png
#  inflated: GTA5/images/01391.png
#  inflated: GTA5/images/01392.png
#  inflated: GTA5/images/01393.png
#  inflated: GTA5/images/01394.png
#  inflated: GTA5/images/01395.png
#  inflated: GTA5/images/01396.png
#  inflated: GTA5/images/01397.png
#  inflated: GTA5/images/01398.png
#  inflated: GTA5/images/01399.png
#  inflated: GTA5/images/01400.png
#  inflated: GTA5/images/01401.png
#  inflated: GTA5/images/01402.png
#  inflated: GTA5/images/01403.png
#  inflated: GTA5/images/01404.png
#  inflated: GTA5/images/01405.png
#  inflated: GTA5/images/01406.png
#  inflated: GTA5/images/01407.png
#  inflated: GTA5/images/01408.png
#  inflated: GTA5/images/01409.png
#  inflated: GTA5/images/01410.png
#  inflated: GTA5/images/01411.png
#  inflated: GTA5/images/01412.png
#  inflated: GTA5/images/01413.png
#  inflated: GTA5/images/01414.png
#  inflated: GTA5/images/01415.png
#  inflated: GTA5/images/01416.png
#  inflated: GTA5/images/01417.png
#  inflated: GTA5/images/01418.png
#  inflated: GTA5/images/01419.png
#  inflated: GTA5/images/01420.png
#  inflated: GTA5/images/01421.png
#  inflated: GTA5/images/01422.png
#  inflated: GTA5/images/01423.png
#  inflated: GTA5/images/01424.png
#  inflated: GTA5/images/01425.png
#  inflated: GTA5/images/01426.png
#  inflated: GTA5/images/01427.png
#  inflated: GTA5/images/01428.png
#  inflated: GTA5/images/01429.png
#  inflated: GTA5/images/01430.png
#  inflated: GTA5/images/01431.png
#  inflated: GTA5/images/01432.png
#  inflated: GTA5/images/01433.png
#  inflated: GTA5/images/01434.png
#  inflated: GTA5/images/01435.png
#  inflated: GTA5/images/01436.png
#  inflated: GTA5/images/01437.png
#  inflated: GTA5/images/01438.png
#  inflated: GTA5/images/01439.png
#  inflated: GTA5/images/01440.png
#  inflated: GTA5/images/01441.png
#  inflated: GTA5/images/01442.png
#  inflated: GTA5/images/01443.png
#  inflated: GTA5/images/01444.png
#  inflated: GTA5/images/01445.png
#  inflated: GTA5/images/01446.png
#  inflated: GTA5/images/01447.png
#  inflated: GTA5/images/01448.png
#  inflated: GTA5/images/01449.png
#  inflated: GTA5/images/01450.png
#  inflated: GTA5/images/01451.png
#  inflated: GTA5/images/01452.png
#  inflated: GTA5/images/01453.png
#  inflated: GTA5/images/01454.png
# ...
#  inflated: GTA5/labels/02017.png
#  inflated: GTA5/labels/02018.png
#  inflated: GTA5/labels/02019.png
#  inflated: GTA5/labels/02020.png
#  inflated: GTA5/labels/02021.png
#  inflated: GTA5/labels/02022.png
#  inflated: GTA5/labels/02023.png
#  inflated: GTA5/labels/02024.png
#  inflated: GTA5/labels/02025.png
#  inflated: GTA5/labels/02026.png
#  inflated: GTA5/labels/02027.png
#  inflated: GTA5/labels/02028.png
#  inflated: GTA5/labels/02029.png
#  inflated: GTA5/labels/02030.png
#  inflated: GTA5/labels/02031.png
#  inflated: GTA5/labels/02032.png
#  inflated: GTA5/labels/02033.png
#  inflated: GTA5/labels/02034.png
#  inflated: GTA5/labels/02035.png
#  inflated: GTA5/labels/02036.png
#  inflated: GTA5/labels/02037.png
#  inflated: GTA5/labels/02038.png
#  inflated: GTA5/labels/02039.png
#  inflated: GTA5/labels/02040.png
#  inflated: GTA5/labels/02041.png
#  inflated: GTA5/labels/02042.png
#  inflated: GTA5/labels/02043.png
#  inflated: GTA5/labels/02044.png
#  inflated: GTA5/labels/02045.png
#  inflated: GTA5/labels/02046.png
#  inflated: GTA5/labels/02047.png
#  inflated: GTA5/labels/02048.png
#  inflated: GTA5/labels/02049.png
#  inflated: GTA5/labels/02050.png
#  inflated: GTA5/labels/02051.png
#  inflated: GTA5/labels/02052.png
#  inflated: GTA5/labels/02053.png
#  inflated: GTA5/labels/02054.png
#  inflated: GTA5/labels/02055.png
#  inflated: GTA5/labels/02056.png
#  inflated: GTA5/labels/02057.png
#  inflated: GTA5/labels/02058.png
#  inflated: GTA5/labels/02059.png
#  inflated: GTA5/labels/02060.png
#  inflated: GTA5/labels/02061.png
#  inflated: GTA5/labels/02062.png
#  inflated: GTA5/labels/02063.png
#  inflated: GTA5/labels/02064.png
#  inflated: GTA5/labels/02065.png
#  inflated: GTA5/labels/02066.png
#  inflated: GTA5/labels/02067.png
#  inflated: GTA5/labels/02068.png
#  inflated: GTA5/labels/02069.png
#  inflated: GTA5/labels/02070.png
#  inflated: GTA5/labels/02071.png
#  inflated: GTA5/labels/02072.png
#  inflated: GTA5/labels/02073.png
#  inflated: GTA5/labels/02074.png
#  inflated: GTA5/labels/02075.png
#  inflated: GTA5/labels/02076.png
#  inflated: GTA5/labels/02077.png
#  inflated: GTA5/labels/02078.png
#  inflated: GTA5/labels/02079.png
#  inflated: GTA5/labels/02080.png
#  inflated: GTA5/labels/02081.png
#  inflated: GTA5/labels/02082.png
#  inflated: GTA5/labels/02083.png
#  inflated: GTA5/labels/02084.png
#  inflated: GTA5/labels/02085.png
#  inflated: GTA5/labels/02086.png
#  inflated: GTA5/labels/02087.png
#  inflated: GTA5/labels/02088.png
#  inflated: GTA5/labels/02089.png
#  inflated: GTA5/labels/02090.png
#  inflated: GTA5/labels/02091.png
#  inflated: GTA5/labels/02092.png
#  inflated: GTA5/labels/02093.png
#  inflated: GTA5/labels/02094.png
#  inflated: GTA5/labels/02095.png
#  inflated: GTA5/labels/02096.png
#  inflated: GTA5/labels/02097.png
#  inflated: GTA5/labels/02098.png
#  inflated: GTA5/labels/02099.png
#  inflated: GTA5/labels/02100.png
#  inflated: GTA5/labels/02101.png
#  inflated: GTA5/labels/02102.png
#  inflated: GTA5/labels/02103.png
#  inflated: GTA5/labels/02104.png
#  inflated: GTA5/labels/02105.png
#  inflated: GTA5/labels/02106.png
#  inflated: GTA5/labels/02107.png
#  inflated: GTA5/labels/02108.png
#  inflated: GTA5/labels/02109.png
#  inflated: GTA5/labels/02110.png
#  inflated: GTA5/labels/02111.png
#  inflated: GTA5/labels/02112.png
#  inflated: GTA5/labels/02113.png
#  inflated: GTA5/labels/02114.png
#  inflated: GTA5/labels/02115.png
#  inflated: GTA5/labels/02116.png
#  inflated: GTA5/labels/02117.png
#  inflated: GTA5/labels/02118.png
#  inflated: GTA5/labels/02119.png
#  inflated: GTA5/labels/02120.png
#  inflated: GTA5/labels/02121.png
#  inflated: GTA5/labels/02122.png
#  inflated: GTA5/labels/02123.png
#  inflated: GTA5/labels/02124.png
#  inflated: GTA5/labels/02125.png
#  inflated: GTA5/labels/02126.png
#  inflated: GTA5/labels/02127.png
#  inflated: GTA5/labels/02128.png
#  inflated: GTA5/labels/02129.png
#  inflated: GTA5/labels/02130.png
#  inflated: GTA5/labels/02131.png
#  inflated: GTA5/labels/02132.png
#  inflated: GTA5/labels/02133.png
#  inflated: GTA5/labels/02134.png
#  inflated: GTA5/labels/02135.png
#  inflated: GTA5/labels/02136.png
#  inflated: GTA5/labels/02137.png
#  inflated: GTA5/labels/02138.png
#  inflated: GTA5/labels/02139.png
#  inflated: GTA5/labels/02140.png
#  inflated: GTA5/labels/02141.png
#  inflated: GTA5/labels/02142.png
#  inflated: GTA5/labels/02143.png
#  inflated: GTA5/labels/02144.png
#  inflated: GTA5/labels/02145.png
#  inflated: GTA5/labels/02146.png
#  inflated: GTA5/labels/02147.png
#  inflated: GTA5/labels/02148.png
#  inflated: GTA5/labels/02149.png
#  inflated: GTA5/labels/02150.png
#  inflated: GTA5/labels/02151.png
#  inflated: GTA5/labels/02152.png
#  inflated: GTA5/labels/02153.png
#  inflated: GTA5/labels/02154.png
#  inflated: GTA5/labels/02155.png
#  inflated: GTA5/labels/02156.png
#  inflated: GTA5/labels/02157.png
#  inflated: GTA5/labels/02158.png
#  inflated: GTA5/labels/02159.png
#  inflated: GTA5/labels/02160.png
#  inflated: GTA5/labels/02161.png
#  inflated: GTA5/labels/02162.png
#  inflated: GTA5/labels/02163.png
#  inflated: GTA5/labels/02164.png
#  inflated: GTA5/labels/02165.png
#  inflated: GTA5/labels/02166.png
#  inflated: GTA5/labels/02167.png
#  inflated: GTA5/labels/02168.png
#  inflated: GTA5/labels/02169.png
#  inflated: GTA5/labels/02170.png
#  inflated: GTA5/labels/02171.png
#  inflated: GTA5/labels/02172.png
#  inflated: GTA5/labels/02173.png
#  inflated: GTA5/labels/02174.png
#  inflated: GTA5/labels/02175.png
#  inflated: GTA5/labels/02176.png
#  inflated: GTA5/labels/02177.png
#  inflated: GTA5/labels/02178.png
#  inflated: GTA5/labels/02179.png
#  inflated: GTA5/labels/02180.png
#  inflated: GTA5/labels/02181.png
#  inflated: GTA5/labels/02182.png
#  inflated: GTA5/labels/02183.png
#  inflated: GTA5/labels/02184.png
#  inflated: GTA5/labels/02185.png
#  inflated: GTA5/labels/02186.png
#  inflated: GTA5/labels/02187.png
#  inflated: GTA5/labels/02188.png
#  inflated: GTA5/labels/02189.png
#  inflated: GTA5/labels/02190.png
#  inflated: GTA5/labels/02191.png
#  inflated: GTA5/labels/02192.png
#  inflated: GTA5/labels/02193.png
#  inflated: GTA5/labels/02194.png
#  inflated: GTA5/labels/02195.png
#  inflated: GTA5/labels/02196.png
#  inflated: GTA5/labels/02197.png
#  inflated: GTA5/labels/02198.png
#  inflated: GTA5/labels/02199.png
#  inflated: GTA5/labels/02200.png
#  inflated: GTA5/labels/02201.png
#  inflated: GTA5/labels/02202.png
#  inflated: GTA5/labels/02203.png
#  inflated: GTA5/labels/02204.png
#  inflated: GTA5/labels/02205.png
#  inflated: GTA5/labels/02206.png
#  inflated: GTA5/labels/02207.png
#  inflated: GTA5/labels/02208.png
#  inflated: GTA5/labels/02209.png
#  inflated: GTA5/labels/02210.png
#  inflated: GTA5/labels/02211.png
#  inflated: GTA5/labels/02212.png
#  inflated: GTA5/labels/02213.png
#  inflated: GTA5/labels/02214.png
#  inflated: GTA5/labels/02215.png
#  inflated: GTA5/labels/02216.png
#  inflated: GTA5/labels/02217.png
#  inflated: GTA5/labels/02218.png
#  inflated: GTA5/labels/02219.png
#  inflated: GTA5/labels/02220.png
#  inflated: GTA5/labels/02221.png
#  inflated: GTA5/labels/02222.png
#  inflated: GTA5/labels/02223.png
#  inflated: GTA5/labels/02224.png
#  inflated: GTA5/labels/02225.png
#  inflated: GTA5/labels/02226.png
#  inflated: GTA5/labels/02227.png
#  inflated: GTA5/labels/02228.png
#  inflated: GTA5/labels/02229.png
#  inflated: GTA5/labels/02230.png
#  inflated: GTA5/labels/02231.png
#  inflated: GTA5/labels/02232.png
#  inflated: GTA5/labels/02233.png
#  inflated: GTA5/labels/02234.png
#  inflated: GTA5/labels/02235.png
#  inflated: GTA5/labels/02236.png
#  inflated: GTA5/labels/02237.png
#  inflated: GTA5/labels/02238.png
#  inflated: GTA5/labels/02239.png
#  inflated: GTA5/labels/02240.png
#  inflated: GTA5/labels/02241.png
#  inflated: GTA5/labels/02242.png
#  inflated: GTA5/labels/02243.png
#  inflated: GTA5/labels/02244.png
#  inflated: GTA5/labels/02245.png
#  inflated: GTA5/labels/02246.png
#  inflated: GTA5/labels/02247.png
#  inflated: GTA5/labels/02248.png
#  inflated: GTA5/labels/02249.png
#  inflated: GTA5/labels/02250.png
#  inflated: GTA5/labels/02251.png
#  inflated: GTA5/labels/02252.png
#  inflated: GTA5/labels/02253.png
#  inflated: GTA5/labels/02254.png
#  inflated: GTA5/labels/02255.png
#  inflated: GTA5/labels/02256.png
#  inflated: GTA5/labels/02257.png
#  inflated: GTA5/labels/02258.png
#  inflated: GTA5/labels/02259.png
#  inflated: GTA5/labels/02260.png
#  inflated: GTA5/labels/02261.png
#  inflated: GTA5/labels/02262.png
#  inflated: GTA5/labels/02263.png
#  inflated: GTA5/labels/02264.png
#  inflated: GTA5/labels/02265.png
#  inflated: GTA5/labels/02266.png
#  inflated: GTA5/labels/02267.png
#  inflated: GTA5/labels/02268.png
#  inflated: GTA5/labels/02269.png
#  inflated: GTA5/labels/02270.png
#  inflated: GTA5/labels/02271.png
#  inflated: GTA5/labels/02272.png
#  inflated: GTA5/labels/02273.png
#  inflated: GTA5/labels/02274.png
#  inflated: GTA5/labels/02275.png
#  inflated: GTA5/labels/02276.png
#  inflated: GTA5/labels/02277.png
#  inflated: GTA5/labels/02278.png
#  inflated: GTA5/labels/02279.png
#  inflated: GTA5/labels/02280.png
#  inflated: GTA5/labels/02281.png
#  inflated: GTA5/labels/02282.png
#  inflated: GTA5/labels/02283.png
#  inflated: GTA5/labels/02284.png
#  inflated: GTA5/labels/02285.png
#  inflated: GTA5/labels/02286.png
#  inflated: GTA5/labels/02287.png
#  inflated: GTA5/labels/02288.png
#  inflated: GTA5/labels/02289.png
#  inflated: GTA5/labels/02290.png
#  inflated: GTA5/labels/02291.png
#  inflated: GTA5/labels/02292.png
#  inflated: GTA5/labels/02293.png
#  inflated: GTA5/labels/02294.png
#  inflated: GTA5/labels/02295.png
#  inflated: GTA5/labels/02296.png
#  inflated: GTA5/labels/02297.png
#  inflated: GTA5/labels/02298.png
#  inflated: GTA5/labels/02299.png
#  inflated: GTA5/labels/02300.png
#  inflated: GTA5/labels/02301.png
#  inflated: GTA5/labels/02302.png
#  inflated: GTA5/labels/02303.png
#  inflated: GTA5/labels/02304.png
#  inflated: GTA5/labels/02305.png
#  inflated: GTA5/labels/02306.png
#  inflated: GTA5/labels/02307.png
#  inflated: GTA5/labels/02308.png
#  inflated: GTA5/labels/02309.png
#  inflated: GTA5/labels/02310.png
#  inflated: GTA5/labels/02311.png
#  inflated: GTA5/labels/02312.png
#  inflated: GTA5/labels/02313.png
#  inflated: GTA5/labels/02314.png
#  inflated: GTA5/labels/02315.png
#  inflated: GTA5/labels/02316.png
#  inflated: GTA5/labels/02317.png
#  inflated: GTA5/labels/02318.png
#  inflated: GTA5/labels/02319.png
#  inflated: GTA5/labels/02320.png
#  inflated: GTA5/labels/02321.png
#  inflated: GTA5/labels/02322.png
#  inflated: GTA5/labels/02323.png
#  inflated: GTA5/labels/02324.png
#  inflated: GTA5/labels/02325.png
#  inflated: GTA5/labels/02326.png
#  inflated: GTA5/labels/02327.png
#  inflated: GTA5/labels/02328.png
#  inflated: GTA5/labels/02329.png
#  inflated: GTA5/labels/02330.png
#  inflated: GTA5/labels/02331.png
#  inflated: GTA5/labels/02332.png
#  inflated: GTA5/labels/02333.png
#  inflated: GTA5/labels/02334.png
#  inflated: GTA5/labels/02335.png
#  inflated: GTA5/labels/02336.png
#  inflated: GTA5/labels/02337.png
#  inflated: GTA5/labels/02338.png
#  inflated: GTA5/labels/02339.png
#  inflated: GTA5/labels/02340.png
#  inflated: GTA5/labels/02341.png
#  inflated: GTA5/labels/02342.png
#  inflated: GTA5/labels/02343.png
#  inflated: GTA5/labels/02344.png
#  inflated: GTA5/labels/02345.png
#  inflated: GTA5/labels/02346.png
#  inflated: GTA5/labels/02347.png
#  inflated: GTA5/labels/02348.png
#  inflated: GTA5/labels/02349.png
#  inflated: GTA5/labels/02350.png
#  inflated: GTA5/labels/02351.png
#  inflated: GTA5/labels/02352.png
#  inflated: GTA5/labels/02353.png
#  inflated: GTA5/labels/02354.png
#  inflated: GTA5/labels/02355.png
#  inflated: GTA5/labels/02356.png
#  inflated: GTA5/labels/02357.png
#  inflated: GTA5/labels/02358.png
#  inflated: GTA5/labels/02359.png
#  inflated: GTA5/labels/02360.png
#  inflated: GTA5/labels/02361.png
#  inflated: GTA5/labels/02362.png
#  inflated: GTA5/labels/02363.png
#  inflated: GTA5/labels/02364.png
#  inflated: GTA5/labels/02365.png
#  inflated: GTA5/labels/02366.png
#  inflated: GTA5/labels/02367.png
#  inflated: GTA5/labels/02368.png
#  inflated: GTA5/labels/02369.png
#  inflated: GTA5/labels/02370.png
#  inflated: GTA5/labels/02371.png
#  inflated: GTA5/labels/02372.png
#  inflated: GTA5/labels/02373.png
#  inflated: GTA5/labels/02374.png
#  inflated: GTA5/labels/02375.png
#  inflated: GTA5/labels/02376.png
#  inflated: GTA5/labels/02377.png
#  inflated: GTA5/labels/02378.png
#  inflated: GTA5/labels/02379.png
#  inflated: GTA5/labels/02380.png
#  inflated: GTA5/labels/02381.png
#  inflated: GTA5/labels/02382.png
#  inflated: GTA5/labels/02383.png
#  inflated: GTA5/labels/02384.png
#  inflated: GTA5/labels/02385.png
#  inflated: GTA5/labels/02386.png
#  inflated: GTA5/labels/02387.png
#  inflated: GTA5/labels/02388.png
#  inflated: GTA5/labels/02389.png
#  inflated: GTA5/labels/02390.png
#  inflated: GTA5/labels/02391.png
#  inflated: GTA5/labels/02392.png
#  inflated: GTA5/labels/02393.png
#  inflated: GTA5/labels/02394.png
#  inflated: GTA5/labels/02395.png
#  inflated: GTA5/labels/02396.png
#  inflated: GTA5/labels/02397.png
#  inflated: GTA5/labels/02398.png
#  inflated: GTA5/labels/02399.png
#  inflated: GTA5/labels/02400.png
#  inflated: GTA5/labels/02401.png
#  inflated: GTA5/labels/02402.png
#  inflated: GTA5/labels/02403.png
#  inflated: GTA5/labels/02404.png
#  inflated: GTA5/labels/02405.png
#  inflated: GTA5/labels/02406.png
#  inflated: GTA5/labels/02407.png
#  inflated: GTA5/labels/02408.png
#  inflated: GTA5/labels/02409.png
#  inflated: GTA5/labels/02410.png
#  inflated: GTA5/labels/02411.png
#  inflated: GTA5/labels/02412.png
#  inflated: GTA5/labels/02413.png
#  inflated: GTA5/labels/02414.png
#  inflated: GTA5/labels/02415.png
#  inflated: GTA5/labels/02416.png
#  inflated: GTA5/labels/02417.png
#  inflated: GTA5/labels/02418.png
#  inflated: GTA5/labels/02419.png
#  inflated: GTA5/labels/02420.png
#  inflated: GTA5/labels/02421.png
#  inflated: GTA5/labels/02422.png
#  inflated: GTA5/labels/02423.png
#  inflated: GTA5/labels/02424.png
#  inflated: GTA5/labels/02425.png
#  inflated: GTA5/labels/02426.png
#  inflated: GTA5/labels/02427.png
#  inflated: GTA5/labels/02428.png
#  inflated: GTA5/labels/02429.png
#  inflated: GTA5/labels/02430.png
#  inflated: GTA5/labels/02431.png
#  inflated: GTA5/labels/02432.png
#  inflated: GTA5/labels/02433.png
#  inflated: GTA5/labels/02434.png
#  inflated: GTA5/labels/02435.png
#  inflated: GTA5/labels/02436.png
#  inflated: GTA5/labels/02437.png
#  inflated: GTA5/labels/02438.png
#  inflated: GTA5/labels/02439.png
#  inflated: GTA5/labels/02440.png
#  inflated: GTA5/labels/02441.png
#  inflated: GTA5/labels/02442.png
#  inflated: GTA5/labels/02443.png
#  inflated: GTA5/labels/02444.png
#  inflated: GTA5/labels/02445.png
#  inflated: GTA5/labels/02446.png
#  inflated: GTA5/labels/02447.png
#  inflated: GTA5/labels/02448.png
#  inflated: GTA5/labels/02449.png
#  inflated: GTA5/labels/02450.png
#  inflated: GTA5/labels/02451.png
#  inflated: GTA5/labels/02452.png
#  inflated: GTA5/labels/02453.png
#  inflated: GTA5/labels/02454.png
#  inflated: GTA5/labels/02455.png
#  inflated: GTA5/labels/02456.png
#  inflated: GTA5/labels/02457.png
#  inflated: GTA5/labels/02458.png
#  inflated: GTA5/labels/02459.png
#  inflated: GTA5/labels/02460.png
#  inflated: GTA5/labels/02461.png
#  inflated: GTA5/labels/02462.png
#  inflated: GTA5/labels/02463.png
#  inflated: GTA5/labels/02464.png
#  inflated: GTA5/labels/02465.png
#  inflated: GTA5/labels/02466.png
#  inflated: GTA5/labels/02467.png
#  inflated: GTA5/labels/02468.png
#  inflated: GTA5/labels/02469.png
#  inflated: GTA5/labels/02470.png
#  inflated: GTA5/labels/02471.png
#  inflated: GTA5/labels/02472.png
#  inflated: GTA5/labels/02473.png
#  inflated: GTA5/labels/02474.png
#  inflated: GTA5/labels/02475.png
#  inflated: GTA5/labels/02476.png
#  inflated: GTA5/labels/02477.png
#  inflated: GTA5/labels/02478.png
#  inflated: GTA5/labels/02479.png
#  inflated: GTA5/labels/02480.png
#  inflated: GTA5/labels/02481.png
#  inflated: GTA5/labels/02482.png
#  inflated: GTA5/labels/02483.png
#  inflated: GTA5/labels/02484.png
#  inflated: GTA5/labels/02485.png
#  inflated: GTA5/labels/02486.png
#  inflated: GTA5/labels/02487.png
#  inflated: GTA5/labels/02488.png
#  inflated: GTA5/labels/02489.png
#  inflated: GTA5/labels/02490.png
#  inflated: GTA5/labels/02491.png
#  inflated: GTA5/labels/02492.png
#  inflated: GTA5/labels/02493.png
#  inflated: GTA5/labels/02494.png
#  inflated: GTA5/labels/02495.png
#  inflated: GTA5/labels/02496.png
#  inflated: GTA5/labels/02497.png
#  inflated: GTA5/labels/02498.png
#  inflated: GTA5/labels/02499.png
#  inflated: GTA5/labels/02500.png

# %% [markdown]
# ### Import methods from TA's repository

# %%
# cloning github repo for model (BiseNet with STDC) and utils, I rewrote manually the Train.py and Cityscapes.py below
import pathlib
print(pathlib.Path.cwd())
# !git clone https://github.com/ClaudiaCuttano/AML_Semantic_DA.git


# importing stuff from the repo we just cloned

# copied from train.py
from AML_Semantic_DA.model.model_stages import BiSeNet  # see https://github.com/ClaudiaCuttano/AML_Semantic_DA/blob/master/model/model_stages.py
from AML_Semantic_DA.utils import poly_lr_scheduler, reverse_one_hot, compute_global_accuracy, fast_hist, per_class_iu # see https://github.com/ClaudiaCuttano/AML_Semantic_DA/blob/master/utils.py
# Out:
# /content
# Cloning into 'AML_Semantic_DA'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 18 (delta 0), reused 0 (delta 0), pack-reused 11
# Receiving objects: 100% (18/18), 10.88 KiB | 10.88 MiB/s, done.

# %%
# taken from the original train.py, not sure what it's for
def str2bool(v):
    """
    It converts a string into a boolean
    """

    if v.lower() in ('yes', 'true', 't', 'y', '1'):
        return True
    elif v.lower() in ('no', 'false', 'f', 'n', '0'):
        return False
    else:
        raise 'Unsupported value encountered.'

# %% [markdown]
# ### Import methods for GTA5
# Clone repo useful to give a label for each pixel.

# %%
import pathlib
print(pathlib.Path.cwd())
# !git clone https://github.com/MichaelFan01/STDC-Seg.git STDC_seg
# importing stuff from the repo we just cloned
# Out:
# /content
# Cloning into 'STDC_seg'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 98 (delta 18), reused 8 (delta 8), pack-reused 70
# Receiving objects: 100% (98/98), 1.93 MiB | 5.85 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %% [markdown]
# ## **Data loader classes + Preprocessing**

# %% [markdown]
# ### Data Pre Processing
# We need to do pre-processing only on **training set** (and not on validation set because on the last one we work with 1024 x 2048 pictures)

# %%
#transforms.CenterCrop((512,1024))
train_transform = transforms.Compose([transforms.Resize((512,1024), transforms.InterpolationMode.BILINEAR),
                                      transforms.ToTensor()
                                      ])
label_transform = transforms.Resize((512,1024), transforms.InterpolationMode.NEAREST)
eval_transform = transforms.Compose([transforms.ToTensor()])


gta_train_transform = transforms.Compose([transforms.Resize((512,1024), transforms.InterpolationMode.BILINEAR),
                                          transforms.ToTensor()
                                          ])
gta_label_transform = transforms.Resize((512,1024), transforms.InterpolationMode.NEAREST)
gta_val_transform = transforms.Compose([transforms.ToTensor()])


#data augmentation
bright_t = transforms.ColorJitter(brightness=[1,2])
contrast_t = transforms.ColorJitter(contrast = [2,5])
saturation_t = transforms.ColorJitter(saturation = [1,3])
hue_t = transforms.ColorJitter(hue = 0.2)
gs_t = transforms.Grayscale(3)
hflip_t = transforms.RandomHorizontalFlip(p = 1)
cc_t = transforms.CenterCrop((256,512))

augmentation_transforms = [bright_t, contrast_t, saturation_t, hue_t, gs_t, hflip_t, cc_t]

#rp_t = transforms.RandomPerspective(p = 1, distortion_scale = 0.5)
#augmentation_transforms = [bright_t, contrast_t, saturation_t, hue_t, gs_t, hflip_t, rp_t]

# %% [markdown]
# ### Cityscapes

# %%
class CityScapes(Dataset):
    def __init__(self, base_root, mode):
        super(CityScapes, self).__init__()

        self.mode = mode
        self.image_paths = [] # images
        self.mask_paths_colored = [] # colored images
        self.mask_paths_bw = [] # labels

        assert(mode == 'train' or mode == 'val')  # just checking for potential issues
        image_folder = f'{base_root}images/{mode}'

        for root, dirs, files in os.walk(image_folder):
            for file_name in files:
                image_path = f'{root}/{file_name}'
                assert(Path(image_path).is_file())
                self.image_paths.append(image_path)

                mask_path_bw = image_path.replace('leftImg8bit', 'gtFine_labelTrainIds')
                mask_path_bw = mask_path_bw.replace('/images/', '/gtFine/')
                assert(Path(mask_path_bw).is_file())
                self.mask_paths_bw.append(mask_path_bw)

                #mask_path_colored = image_path.replace('leftImg8bit', 'gtFine_labelTrainIds')
                #mask_path_colored = mask_path_colored.replace('/images/', '/gtFine/')
                #assert(Path(mask_path_colored).is_file())
                #self.mask_paths_colored.append(mask_path_colored)

        if self.mode == 'train':
            self.image_transform = train_transform
        if self.mode == 'val':
            self.image_transform = eval_transform
        self.label_transform = label_transform

        assert (len(self.image_paths) != 0)
        assert (len(self.image_paths) == len(self.mask_paths_bw))
        #assert (len(self.image_paths) == len(self.mask_paths_colored))


    def __getitem__(self, index):

        image = Image.open(self.image_paths[index]).convert('RGB')
        label = Image.open(self.mask_paths_bw[index])

        if self.mode == 'train':
            label = np.array(self.label_transform(label))[np.newaxis, :]
        else:
            label = np.array(label)[np.newaxis, :]

        image = self.image_transform(image)

        return image, label


    def __len__(self):
        return len(self.image_paths)

# %% [markdown]
# ### GTA5

# %%
class GTA5(Dataset):
    def __init__(self, base_root, mode, augmentation=False, train_test_rateo=2/3):
        super(GTA5, self).__init__()

        self.mode = mode
        self.image_paths = [] # images
        self.label_paths = [] # labels
        self.train_test_rateo = train_test_rateo
        self.augmentation = augmentation
        with open('STDC_seg/cityscapes_info.json', 'r') as fr:
            labels_info = json.load(fr)
        self.label_map = {el['id']: el['trainId'] for el in labels_info}
        self.label_map.update({34 : 255})

        assert(mode == 'train' or mode == 'val')  # just checking for potential issues

        image_folder = f'{base_root}images'

        for root, dirs, files in os.walk(image_folder):
            for file_name in files:
                image_path = f'{root}/{file_name}'
                assert(Path(image_path).is_file())
                self.image_paths.append(image_path)

                label_path = image_path.replace('/images/', '/labels/')
                assert(Path(label_path).is_file())
                self.label_paths.append(label_path)

        l = int(len(self.image_paths) * self.train_test_rateo)
        if self.mode == 'train':
            self.image_paths = self.image_paths[:l]
            self.label_paths = self.label_paths[:l]
            self.image_transform = gta_train_transform
            self.label_transform = gta_label_transform
        elif self.mode == 'val':
            self.image_paths = self.image_paths[l:]
            self.label_paths = self.label_paths[l:]
            self.image_transform = gta_val_transform

        assert (len(self.image_paths) != 0)
        assert (len(self.image_paths) == len(self.label_paths))


    def __getitem__(self, index):

        image = Image.open(self.image_paths[index]).convert('RGB')
        image = self.image_transform(image)

        label = Image.open(self.label_paths[index])
        if self.mode == 'train':
            label = self.label_transform(label)

        if self.augmentation and random.choice([True, False]) and self.mode == 'train':
            idx = random.randint(0, 6)

            image = augmentation_transforms[idx](image)

            if hflip_t is augmentation_transforms[idx] or cc_t is augmentation_transforms[idx]:
                label = augmentation_transforms[idx](label)

            if cc_t is augmentation_transforms[idx]:
                rimage_t = transforms.Resize((512,1024), transforms.InterpolationMode.BILINEAR, antialias=None)
                rlabel_t = transforms.Resize((512,1024), transforms.InterpolationMode.NEAREST, antialias=None)
                image = rimage_t(image)
                label = augmentation_transforms[idx](label)
                label = rlabel_t(label)

        label = np.array(label).astype(np.int64)[np.newaxis, :]
        label = self.convert_labels(label)

        return image, label


    def convert_labels(self, label):
        for k, v in self.label_map.items():
            label[label == k] = v
        return label


    def __len__(self):
        return len(self.image_paths)

# %% [markdown]
# ## **Architecture**
# BiSeNet as Domain Adaptation Neural Network (DANN)

# %%
class FCDiscriminator(nn.Module):

    def __init__(self, num_classes, ndf = 64):
        super(FCDiscriminator, self).__init__()

        self.conv1 = nn.Conv2d(num_classes, ndf, kernel_size=4, stride=2, padding=1)
        self.conv2 = nn.Conv2d(ndf, ndf*2, kernel_size=4, stride=2, padding=1)
        self.conv3 = nn.Conv2d(ndf*2, ndf*4, kernel_size=4, stride=2, padding=1)
        self.conv4 = nn.Conv2d(ndf*4, ndf*8, kernel_size=4, stride=2, padding=1)
        self.classifier = nn.Conv2d(ndf*8, 1, kernel_size=4, stride=2, padding=1)

        self.leaky_relu = nn.LeakyReLU(negative_slope=0.2, inplace=True)
        self.up_sample = nn.Upsample(scale_factor=32, mode='bilinear')
        #self.sigmoid = nn.Sigmoid()


    def forward(self, x):
        x = self.conv1(x)
        x = self.leaky_relu(x)
        x = self.conv2(x)
        x = self.leaky_relu(x)
        x = self.conv3(x)
        x = self.leaky_relu(x)
        x = self.conv4(x)
        x = self.leaky_relu(x)
        x = self.classifier(x)
        x = self.up_sample(x)
        #x = self.sigmoid(x)

        return x

# %% [markdown]
# ## **Train + Validation**

# %% [markdown]
# ### Base Training

# %%
from torch.autograd import Variable

def train(args, model, optimizer, dataloader_train, dataloader_val):
    print("start train without domain adaptation")
    # for SummaryWriter read (https://pytorch.org/docs/stable/tensorboard.html)
    writer = SummaryWriter(log_dir='/content/Drive/MyDrive/AML project/logs', comment=''.format(args.optimizer)) # log is in run/ folder

    scaler = amp.GradScaler()

    loss_func = torch.nn.CrossEntropyLoss(ignore_index=255)
    max_miou = 0
    step = 0

    for epoch in range(args.epoch_start_i+1, args.num_epochs+1):
        lr = poly_lr_scheduler(optimizer, args.learning_rate, iter=epoch, max_iter=args.num_epochs)
        model.train() # Sets module in training mode
        tq = tqdm(total=len(dataloader_train) * args.batch_size)
        tq.set_description('epoch %d, lr %f' % (epoch, lr))
        loss_record = []

        for i, (data, label) in enumerate(dataloader_train):
            data = data.cuda()
            label = label.long().cuda()
            optimizer.zero_grad() # Zero-ing the gradients
            # From: [batch_size, height, width, channels]
            # To: [batch_size, channels, height, width]
            #data = data.permute(0, 3, 1, 2)

            with amp.autocast():
                output, out16, out32 = model(data)  # Forward pass to the network
                # Compute loss based on output and ground truth
                loss1 = loss_func(output, label.squeeze(1))
                loss2 = loss_func(out16, label.squeeze(1))
                loss3 = loss_func(out32, label.squeeze(1))
                loss = loss1 + loss2 + loss3  # sum of losses

            # Compute gradients for each layer and update weights
            scaler.scale(loss).backward() # backward pass: computes gradients
            scaler.step(optimizer)        # update weights based on accumulated gradients
            scaler.update()

            tq.update(args.batch_size)
            tq.set_postfix(loss='%.6f' % loss)
            step += 1
            writer.add_scalar('loss_step', loss, step)
            loss_record.append(loss.item())
        tq.close()
        loss_train_mean = np.mean(loss_record)
        writer.add_scalar('epoch/loss_epoch_train', float(loss_train_mean), epoch)
        print('loss for train : %f' % (loss_train_mean))

        if epoch % args.checkpoint_step == 0 and epoch != 0:
            import os
            if not os.path.isdir(args.save_model_path):
                os.mkdir(args.save_model_path)
            torch.save(model.module.state_dict(), f'{args.save_model_path}Saved_model_epoch_{epoch}.pth')

        if epoch % args.validation_step == 0 and epoch != args.num_epochs:
            precision, miou = val(args, model, dataloader_val)  # val() function call
            if miou > max_miou:
                max_miou = miou
                import os
                os.makedirs(args.save_model_path, exist_ok=True)
                torch.save(model.module.state_dict(), f'{args.save_model_path}Best_model_epoch_{epoch}.pth')
            writer.add_scalar('epoch/precision_val', precision, epoch)
            writer.add_scalar('epoch/miou val', miou, epoch)

# %% [markdown]
# ### Domain Adaptation Training

# %%
from torch.autograd import Variable


def train_da(args, model, optimizer, model_D, optimizer_D, dataloader_train, dataloader_val, domain_adapt=False, dataloader_target=None):
    print("start train with domain adaptation")
    # for SummaryWriter read (https://pytorch.org/docs/stable/tensorboard.html)
    writer = SummaryWriter(log_dir='/content/Drive/MyDrive/AML project/logs', comment=''.format(args.optimizer)) # log is in run/ folder

    scaler = amp.GradScaler()

    loss_func_G = torch.nn.CrossEntropyLoss(ignore_index=255)
    loss_func_adv = torch.nn.BCEWithLogitsLoss()
    loss_func_D = torch.nn.BCEWithLogitsLoss()

    max_miou = 0
    step = 0

    # see (https://www.github.com/wasidennis/AdaptSegNet/blob/master/train_gta2cityscapes_multi)
    print("Train DA")

    LAMBDA_ADV_TARGET = 0.001

    dataloader_len = min(len(dataloader_train), len(dataloader_target))
    for epoch in range(args.epoch_start_i+1, args.num_epochs+1):
        lr = poly_lr_scheduler(optimizer, args.learning_rate, iter=epoch-1, max_iter=args.num_epochs)
        lr_D = poly_lr_scheduler(optimizer_D, args.learning_rate_D, iter=epoch-1, max_iter=args.num_epochs)

        model.train()
        model_D.train()

        tq = tqdm(total=dataloader_len * args.batch_size)

        tq.set_description('epoch %d, lr %f, lr_discriminator %f' % (epoch, lr, lr_D))

        # set the ground truth for the discriminator
        source_label = 0
        target_label = 1
        # initiate lists to track the losses
        loss_G_record = []                                                       # track the Segmentation loss
        loss_adv_record = []                                                     # track the advarsirial loss
        loss_D_record = []                                                       # track the discriminator loss

        source_train_loader = enumerate(dataloader_train)
        s_size = len(dataloader_train)
        target_loader = enumerate(dataloader_target)
        t_size = len(dataloader_target)

        for i in range(dataloader_len):

            optimizer.zero_grad()
            optimizer_D.zero_grad()

            # =====================================
            # train Generator G:
            # =====================================

            for param in model_D.parameters():
                param.requires_grad = False

            # Train with source:
            # =================================

            _, batch = next(source_train_loader)
            data, label = batch
            data = data.cuda()
            label = label.long().cuda()

            with amp.autocast():
                output_s, out16, out32 = model(data)
                loss1 = loss_func_G(output_s, label.squeeze(1))
                loss2 = loss_func_G(out16, label.squeeze(1))
                loss3 = loss_func_G(out32, label.squeeze(1))
                loss_G = loss1 + loss2 + loss3

            scaler.scale(loss_G).backward()

            # Train with target:
            # =================================

            _, batch = next(target_loader)

            data, _ = batch
            data = data.cuda()
            with amp.autocast():

                output_t, _, _ = model(data)
                D_out = model_D(F.softmax(output_t))
                loss_adv = loss_func_adv(D_out , Variable(torch.FloatTensor(D_out.data.size()).fill_(source_label)).cuda() )  # Generator try to fool the discriminator
                loss_adv = loss_adv * LAMBDA_ADV_TARGET

            scaler.scale(loss_adv).backward()

            # =====================================
            # train Discriminator D:
            # =====================================

            for param in model_D.parameters():
                param.requires_grad = True

            # Train with source:
            # =================================

            output_s = output_s.detach()
            with amp.autocast():
                D_out = model_D(F.softmax(output_s))                                                                   # we feed the discriminator with the output of the G-model
                loss_D = loss_func_D(D_out, Variable(torch.FloatTensor(D_out.data.size()).fill_(source_label)).cuda())
                loss_D = loss_D / 2
            scaler.scale(loss_D).backward()

            # Train with target:
            # =================================

            output_t = output_t.detach()
            with amp.autocast():
                D_out = model_D(F.softmax(output_t))  # we feed the discriminator with the output of the model
                loss_D = loss_func_D(D_out, Variable(torch.FloatTensor(D_out.data.size()).fill_(target_label)).cuda())  # add the adversarial loss
                loss_D = loss_D / 2
            scaler.scale(loss_D).backward()

            tq.update(args.batch_size)
            losses = {"loss_seg" : '%.6f' %(loss_G.item())  , "loss_adv" : '%.6f' %(loss_adv.item()) , "loss_D" : '%.6f'%(loss_D.item()) } # add dictionary to print losses
            tq.set_postfix(losses)

            loss_G_record.append(loss_G.item())
            loss_adv_record.append(loss_adv.item())
            loss_D_record.append(loss_D.item())
            step += 1
            writer.add_scalar('loss_G_step', loss_G, step)  # track the segmentation loss
            writer.add_scalar('loss_adv_step', loss_adv, step)  # track the adversarial loss
            writer.add_scalar('loss_D_step', loss_D, step)  # track the discreminator loss
            scaler.step(optimizer)  # update the optimizer for genarator
            scaler.step(optimizer_D)  # update the optimizer for discriminator
            scaler.update()
        tq.close()

        loss_seg_record_mean = np.mean(loss_G_record)
        loss_adv_record_mean = np.mean(loss_adv_record)
        loss_D_record_mean = np.mean(loss_D_record)
        loss_mean = np.mean([loss_seg_record_mean, loss_adv_record_mean, loss_D_record_mean])
        writer.add_scalar('epoch/loss_epoch_train', float(loss_mean), epoch)
        print(f'loss for train :\n - Segmentation: {loss_seg_record_mean}\n - Adversarial: {loss_adv_record_mean}\n - Discriminator: {loss_D_record_mean}')

        if epoch % args.checkpoint_step == 0 and epoch != 0:
            import os
            if not os.path.isdir(args.save_model_path):
                os.mkdir(args.save_model_path)
            torch.save(model.module.state_dict(), f'{args.save_model_path}DA_Saved_model_epoch_{epoch}.pth')

        if epoch % args.validation_step == 0 and epoch != args.num_epochs:
            precision, miou = val(args, model, dataloader_val)  # val() function call
            if miou > max_miou:
                max_miou = miou
                import os
                os.makedirs(args.save_model_path, exist_ok=True)
                torch.save(model.module.state_dict(), f'{args.save_model_path}DA_Best_model_epoch_{epoch}.pth')
            writer.add_scalar('epoch/precision_val', precision, epoch)
            writer.add_scalar('epoch/miou val', miou, epoch)

# %% [markdown]
# ### Validation

# %%
def val(args, model, dataloader):
    print('start val!')
    with torch.no_grad():
        model.eval()
        precision_record = []
        hist = np.zeros((args.num_classes, args.num_classes))
        tq = tqdm(total=len(dataloader))
        tq.set_description('Validation')
        for i, (data, label) in enumerate(dataloader):
            label = label.type(torch.LongTensor)
            data = data.cuda()
            label = label.long().cuda()

            # get RGB predict image
            predict, _, _ = model(data)
            predict = predict.squeeze(0)
            predict = reverse_one_hot(predict)
            predict = np.array(predict.cpu())

            # get RGB label image
            label = label.squeeze()
            label = np.array(label.cpu())

            # compute per pixel accuracy
            precision = compute_global_accuracy(predict, label)
            hist += fast_hist(label.flatten(), predict.flatten(), args.num_classes)

            # there is no need to transform the one-hot array to visual RGB array
            # predict = colour_code_segmentation(np.array(predict), label_info)
            # label = colour_code_segmentation(np.array(label), label_info)
            precision_record.append(precision)

            tq.update(1)

        tq.close()
        precision = np.mean(precision_record)
        miou_list = per_class_iu(hist)
        miou = np.mean(miou_list)
        print('\nprecision per pixel for test: %.3f' % precision)
        print('mIoU for validation: %.3f' % miou)
        print(f'mIoU per class: {miou_list}')

        return precision, miou

# %% [markdown]
# ## **Plots**

# %% [markdown]
# ### Loss plot

# %%
"""
tr = [x[0] for x in loss_list]
vl = [x[1] for x in loss_list]

print(tr)
print(vl)

plt.figure()
plt.title("Loss comparison")
plt.plot(list(range(1, NUM_EPOCHS + 1, 1)), tr, label = 'training loss')
plt.plot(list(range(1, NUM_EPOCHS + 1, 1)), vl, label = 'validation loss')
plt.xlabel("# epochs")
plt.ylabel("Loss")
plt.legend()
plt.savefig(PLOTS + f'/loss_{OPTIM}_{np.log10(LR):.0f}_{NUM_EPOCHS}_{SCHEDULER}.png')
plt.show()
"""
# Out:
# '\ntr = [x[0] for x in loss_list]\nvl = [x[1] for x in loss_list]\n\nprint(tr)\nprint(vl)\n\nplt.figure()\nplt.title("Loss comparison")\nplt.plot(list(range(1, NUM_EPOCHS + 1, 1)), tr, label = \'training loss\')\nplt.plot(list(range(1, NUM_EPOCHS + 1, 1)), vl, label = \'validation loss\')\nplt.xlabel("# epochs")\nplt.ylabel("Loss")\nplt.legend()\nplt.savefig(PLOTS + f\'/loss_{OPTIM}_{np.log10(LR):.0f}_{NUM_EPOCHS}_{SCHEDULER}.png\')\nplt.show()\n'

# %% [markdown]
# ### Accuracy (mIOU) plot

# %%
"""
tr = [x[0] for x in acc_list]
vl = [x[1] for x in acc_list]

plt.figure()
plt.title("Accuracy comparison")
plt.plot(list(range(1, NUM_EPOCHS + 1, 1)), tr, label = 'training accuracy')
plt.plot(list(range(1, NUM_EPOCHS + 1, 1)), vl, label = 'validation accuracy')
plt.xlabel("# epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.savefig(PLOTS + f'/accuracy_{OPTIM}_{np.log10(LR):.0f}_{NUM_EPOCHS}_{SCHEDULER}.png')
plt.show()
"""
# Out:
# '\ntr = [x[0] for x in acc_list]\nvl = [x[1] for x in acc_list]\n\nplt.figure()\nplt.title("Accuracy comparison")\nplt.plot(list(range(1, NUM_EPOCHS + 1, 1)), tr, label = \'training accuracy\')\nplt.plot(list(range(1, NUM_EPOCHS + 1, 1)), vl, label = \'validation accuracy\')\nplt.xlabel("# epochs")\nplt.ylabel("Accuracy")\nplt.legend()\nplt.savefig(PLOTS + f\'/accuracy_{OPTIM}_{np.log10(LR):.0f}_{NUM_EPOCHS}_{SCHEDULER}.png\')\nplt.show()\n'

# %% [markdown]
# ## **Test**

# %%
"""
net = net.to(DEVICE) # this will bring the network to GPU if DEVICE is cuda
net.train(False) # Set Network to evaluation mode

# comando duale per caricare la rete migliore in net dal file .pth
# per recuparlo --> load_state_dict()
# torch.nn.Module.load_state_dict() -> it loads a model’s parameter dictionary using a deserialized state_dict. (visit https://pytorch.org/tutorials/beginner/saving_loading_models.html)

running_corrects = 0
for images, labels in tqdm(test_dataloader):
  images = images.to(DEVICE)
  labels = labels.to(DEVICE)

  # Forward Pass
  outputs = net(images)

  # Get predictions
  _, preds = torch.max(outputs.data, 1)

  # Update Corrects
  running_corrects += torch.sum(preds == labels.data).data.item()

# Calculate Accuracy
accuracy = running_corrects / float(len(test_dataset))

print('Test Accuracy: {}'.format(accuracy))
"""
# Out:
# "\nnet = net.to(DEVICE) # this will bring the network to GPU if DEVICE is cuda\nnet.train(False) # Set Network to evaluation mode\n\n# comando duale per caricare la rete migliore in net dal file .pth\n# per recuparlo --> load_state_dict()\n# torch.nn.Module.load_state_dict() -> it loads a model’s parameter dictionary using a deserialized state_dict. (visit https://pytorch.org/tutorials/beginner/saving_loading_models.html)\n\nrunning_corrects = 0\nfor images, labels in tqdm(test_dataloader):\n  images = images.to(DEVICE)\n  labels = labels.to(DEVICE)\n\n  # Forward Pass\n  outputs = net(images)\n\n  # Get predictions\n  _, preds = torch.max(outputs.data, 1)\n\n  # Update Corrects\n  running_corrects += torch.sum(preds == labels.data).data.item()\n\n# Calculate Accuracy\naccuracy = running_corrects / float(len(test_dataset))\n\nprint('Test Accuracy: {}'.format(accuracy))\n"

# %% [markdown]
# ## **Main**
# Prepare arguments, Datasets, Dataloaders, model, training and test

# %%
def main(args, eval_only=False):

    n_classes = args.num_classes
    mode = args.mode
    train_root = args.train_root
    val_root = args.val_root
    target_root = args.train_root
    domain_adapt = args.domain_adaptation

    # defining the training, validation (and target for domain adaptation) datasets and dataloaders
    if train_root == 'GTA5/':
        if train_root != val_root: # if we only use GTA5 for training, use the entire dataset and don't leave a portion for testing
            train_dataset = GTA5(train_root, 'train', args.training_augmentation, 1)
        else:
            train_dataset = GTA5(train_root, 'train', args.training_augmentation)
    else:
        train_dataset = CityScapes(train_root, 'train')

    if val_root == 'GTA5/':
        val_dataset = GTA5(val_root, 'val')
    else:
        val_dataset = CityScapes(val_root, 'val')

    if target_root == 'GTA5/':
        target_dataset = GTA5(target_root, 'train')
    else:
        target_dataset = CityScapes(target_root, 'train')



    dataloader_train = DataLoader(train_dataset,
                      batch_size=args.batch_size,
                      shuffle=True,
                      num_workers=args.num_workers,
                      pin_memory=False,
                      drop_last=True)

    dataloader_val = DataLoader(val_dataset,
                      batch_size=1,
                      shuffle=False,
                      num_workers=args.num_workers,
                      drop_last=False)

    dataloader_target = DataLoader(target_dataset,
                      batch_size=args.batch_size,
                      shuffle=True,
                      num_workers=args.num_workers,
                      pin_memory=False,
                      drop_last=True)

    ## model
    model = BiSeNet(backbone=args.backbone, n_classes=n_classes, pretrain_model=args.pretrain_path, use_conv_last=args.use_conv_last)

    if args.epoch_start_i != 0:
        print(f'loading data from saved model {args.saved_model}')
        model.load_state_dict(torch.load(f'{args.save_model_path}{args.saved_model}'))

    if torch.cuda.is_available() and args.use_gpu:
        model = torch.nn.DataParallel(model).cuda()

    ## optimizer
    # build optimizer
    if args.optimizer == 'rmsprop':
        optimizer = torch.optim.RMSprop(model.parameters(), args.learning_rate)
    elif args.optimizer == 'sgd':
        optimizer = torch.optim.SGD(model.parameters(), args.learning_rate, momentum=0.9, weight_decay=1e-4)
    elif args.optimizer == 'adam':
        optimizer = torch.optim.Adam(model.parameters(), args.learning_rate)
    else:  # rmsprop
        print('not supported optimizer \n')
        return None

    if domain_adapt:
        # init Discriminator
        model_D = FCDiscriminator(args.num_classes)

        model_D = model_D.cuda()

        if args.optimizer_D == 'rmsprop':
            optimizer_D = torch.optim.RMSprop(model_D.parameters(), args.learning_rate_D)
        elif args.optimizer_D == 'sgd':
            optimizer_D = torch.optim.SGD(model_D.parameters(), args.learning_rate_D, momentum=0.9, weight_decay=1e-4)
        elif args.optimizer_D == 'adam':
            optimizer_D = torch.optim.Adam(model_D.parameters(), args.learning_rate_D, betas=(0.9, 0.99))
        else:  # rmsprop
            print('not supported optimizer \n')
            return None

    if not eval_only: #this is for when we only care about evaluating a saved model and not about training
        if domain_adapt:
            ## train loop for domain adaptation
            train_da(args, model, optimizer, model_D, optimizer_D, dataloader_train, dataloader_val, domain_adapt=domain_adapt, dataloader_target=dataloader_target)
        else:
            ## normal train loop
            train(args, model, optimizer, dataloader_train, dataloader_val)
    # final test
    val(args, model, dataloader_val)

# %% [markdown]
# ### main execution

# %%
class arguments():
    mode = 'train'
    backbone = 'CatmodelSmall'
    pretrain_path = "/content/Drive/MyDrive/Colab Notebooks/checkpoints/STDCNet813M_73.91.tar"
    use_conv_last = False
    num_epochs = 50
    epoch_start_i = 0
    checkpoint_step = 1
    validation_step = 5
    crop_height = 512
    crop_width = 1024
    batch_size = 8
    learning_rate = 1e-3
    learning_rate_D = 1e-4
    num_workers = 2
    num_classes = 19
    cuda = '0'
    use_gpu = True
    save_model_path = '/content/Drive/MyDrive/Colab Notebooks/Partial models/'
    saved_model = f'DA_Saved_model_epoch_{epoch_start_i}.pth'
    optimizer = 'adam'
    optimizer_D = 'adam'
    loss = 'crossentropy'
    #'Cityscapes/Cityspaces/'
    #'GTA5/'
    train_root = 'GTA5/'
    val_root ='Cityscapes/Cityspaces/'
    target_root = 'Cityscapes/Cityspaces/'
    training_augmentation = True
    domain_adaptation = True
main_args = arguments()

main(main_args, eval_only=False)
# Out:
# use pretrain model /content/Drive/MyDrive/Colab Notebooks/checkpoints/STDCNet813M_73.91.tar
# start train with domain adaptation
# Train DA
#   0%|          | 0/1664 [00:00<?, ?it/s]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   0%|          | 0/1664 [00:00<?, ?it/s]<ipython-input-21-5a81cf3a6fe3>:87: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   D_out = model_D(F.softmax(output_t))
# <ipython-input-21-5a81cf3a6fe3>:105: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   D_out = model_D(F.softmax(output_s))                                                                   # we feed the discriminator with the output of the G-model
# <ipython-input-21-5a81cf3a6fe3>:115: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   D_out = model_D(F.softmax(output_t))  # we feed the discriminator with the output of the model
#
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   0%|          | 4/1664 [00:02<15:46,  1.75it/s]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   0%|          | 4/1664 [00:02<15:46,  1.75it/s, loss_seg=9.624139, loss_adv=0.000693, loss_D=0.346712]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   0%|          | 8/1664 [00:02<09:07,  3.03it/s, loss_seg=9.624139, loss_adv=0.000693, loss_D=0.346712]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   0%|          | 8/1664 [00:02<09:07,  3.03it/s, loss_seg=9.328081, loss_adv=0.000702, loss_D=0.342211]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   1%|          | 12/1664 [00:04<08:37,  3.19it/s, loss_seg=9.328081, loss_adv=0.000702, loss_D=0.342211]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   1%|          | 12/1664 [00:04<08:37,  3.19it/s, loss_seg=9.438750, loss_adv=0.000437, loss_D=0.520283]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   1%|          | 16/1664 [00:04<07:00,  3.92it/s, loss_seg=9.438750, loss_adv=0.000437, loss_D=0.520283]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   1%|          | 16/1664 [00:04<07:00,  3.92it/s, loss_seg=9.137974, loss_adv=0.000677, loss_D=0.354903]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   1%|          | 20/1664 [00:05<06:41,  4.10it/s, loss_seg=9.137974, loss_adv=0.000677, loss_D=0.354903]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   1%|          | 20/1664 [00:05<06:41,  4.10it/s, loss_seg=8.654633, loss_adv=0.000702, loss_D=0.342005]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   1%|▏         | 24/1664 [00:06<05:57,  4.59it/s, loss_seg=8.654633, loss_adv=0.000702, loss_D=0.342005]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   1%|▏         | 24/1664 [00:06<05:57,  4.59it/s, loss_seg=8.187090, loss_adv=0.000690, loss_D=0.347992]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   2%|▏         | 28/1664 [00:07<06:31,  4.18it/s, loss_seg=8.187090, loss_adv=0.000690, loss_D=0.347992]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   2%|▏         | 28/1664 [00:07<06:31,  4.18it/s, loss_seg=7.797142, loss_adv=0.000697, loss_D=0.344871]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   2%|▏         | 32/1664 [00:08<05:51,  4.64it/s, loss_seg=7.797142, loss_adv=0.000697, loss_D=0.344871]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   2%|▏         | 32/1664 [00:08<05:51,  4.64it/s, loss_seg=7.272046, loss_adv=0.000720, loss_D=0.333503]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   2%|▏         | 36/1664 [00:08<05:47,  4.68it/s, loss_seg=7.272046, loss_adv=0.000720, loss_D=0.333503]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   2%|▏         | 36/1664 [00:08<05:47,  4.68it/s, loss_seg=6.974798, loss_adv=0.000689, loss_D=0.350214]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   2%|▏         | 40/1664 [00:09<05:33,  4.87it/s, loss_seg=6.974798, loss_adv=0.000689, loss_D=0.350214]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   2%|▏         | 40/1664 [00:09<05:33,  4.87it/s, loss_seg=6.085812, loss_adv=0.000635, loss_D=0.377983]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   3%|▎         | 44/1664 [00:11<07:15,  3.72it/s, loss_seg=6.085812, loss_adv=0.000635, loss_D=0.377983]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   3%|▎         | 44/1664 [00:11<07:15,  3.72it/s, loss_seg=5.892298, loss_adv=0.000598, loss_D=0.400711]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   3%|▎         | 48/1664 [00:12<06:42,  4.02it/s, loss_seg=5.892298, loss_adv=0.000598, loss_D=0.400711]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   3%|▎         | 48/1664 [00:12<06:42,  4.02it/s, loss_seg=5.840822, loss_adv=0.000924, loss_D=0.254322]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   3%|▎         | 52/1664 [00:13<07:31,  3.57it/s, loss_seg=5.840822, loss_adv=0.000924, loss_D=0.254322]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   3%|▎         | 52/1664 [00:13<07:31,  3.57it/s, loss_seg=5.259713, loss_adv=0.000747, loss_D=0.321122]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   3%|▎         | 56/1664 [00:14<06:28,  4.14it/s, loss_seg=5.259713, loss_adv=0.000747, loss_D=0.321122]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   3%|▎         | 56/1664 [00:14<06:28,  4.14it/s, loss_seg=4.284785, loss_adv=0.000707, loss_D=0.339831]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   4%|▎         | 60/1664 [00:15<06:30,  4.11it/s, loss_seg=4.284785, loss_adv=0.000707, loss_D=0.339831]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   4%|▎         | 60/1664 [00:15<06:30,  4.11it/s, loss_seg=5.048747, loss_adv=0.000687, loss_D=0.349508]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   4%|▍         | 64/1664 [00:15<05:54,  4.51it/s, loss_seg=5.048747, loss_adv=0.000687, loss_D=0.349508]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   4%|▍         | 64/1664 [00:15<05:54,  4.51it/s, loss_seg=4.377427, loss_adv=0.001072, loss_D=0.225814]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   4%|▍         | 68/1664 [00:16<06:09,  4.31it/s, loss_seg=4.377427, loss_adv=0.001072, loss_D=0.225814]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   4%|▍         | 68/1664 [00:16<06:09,  4.31it/s, loss_seg=4.695491, loss_adv=0.000640, loss_D=0.378266]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   4%|▍         | 72/1664 [00:17<05:30,  4.82it/s, loss_seg=4.695491, loss_adv=0.000640, loss_D=0.378266]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   4%|▍         | 72/1664 [00:17<05:30,  4.82it/s, loss_seg=4.075437, loss_adv=0.000848, loss_D=0.283674]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   5%|▍         | 76/1664 [00:18<05:21,  4.94it/s, loss_seg=4.075437, loss_adv=0.000848, loss_D=0.283674]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   5%|▍         | 76/1664 [00:18<05:21,  4.94it/s, loss_seg=4.664156, loss_adv=0.000883, loss_D=0.269341]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   5%|▍         | 80/1664 [00:18<05:02,  5.24it/s, loss_seg=4.664156, loss_adv=0.000883, loss_D=0.269341]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   5%|▍         | 80/1664 [00:18<05:02,  5.24it/s, loss_seg=4.294844, loss_adv=0.000737, loss_D=0.329934]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   5%|▌         | 84/1664 [00:19<05:33,  4.74it/s, loss_seg=4.294844, loss_adv=0.000737, loss_D=0.329934]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   5%|▌         | 84/1664 [00:19<05:33,  4.74it/s, loss_seg=3.829113, loss_adv=0.000669, loss_D=0.360869]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   5%|▌         | 88/1664 [00:20<05:11,  5.05it/s, loss_seg=3.829113, loss_adv=0.000669, loss_D=0.360869]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   5%|▌         | 88/1664 [00:20<05:11,  5.05it/s, loss_seg=3.914180, loss_adv=0.000662, loss_D=0.362742]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▌         | 92/1664 [00:21<06:05,  4.31it/s, loss_seg=3.914180, loss_adv=0.000662, loss_D=0.362742]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▌         | 92/1664 [00:21<06:05,  4.31it/s, loss_seg=3.336803, loss_adv=0.000655, loss_D=0.366713]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▌         | 96/1664 [00:22<05:28,  4.78it/s, loss_seg=3.336803, loss_adv=0.000655, loss_D=0.366713]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▌         | 96/1664 [00:22<05:28,  4.78it/s, loss_seg=3.493733, loss_adv=0.000648, loss_D=0.370425]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▌         | 100/1664 [00:23<05:30,  4.73it/s, loss_seg=3.493733, loss_adv=0.000648, loss_D=0.370425]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▌         | 100/1664 [00:23<05:30,  4.73it/s, loss_seg=4.900624, loss_adv=0.000658, loss_D=0.364734]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▋         | 104/1664 [00:24<05:25,  4.79it/s, loss_seg=4.900624, loss_adv=0.000658, loss_D=0.364734]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▋         | 104/1664 [00:24<05:25,  4.79it/s, loss_seg=3.382540, loss_adv=0.000663, loss_D=0.362108]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▋         | 108/1664 [00:25<07:07,  3.64it/s, loss_seg=3.382540, loss_adv=0.000663, loss_D=0.362108]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   6%|▋         | 108/1664 [00:25<07:07,  3.64it/s, loss_seg=4.139212, loss_adv=0.000679, loss_D=0.353619]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   7%|▋         | 112/1664 [00:26<06:26,  4.02it/s, loss_seg=4.139212, loss_adv=0.000679, loss_D=0.353619]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   7%|▋         | 112/1664 [00:26<06:26,  4.02it/s, loss_seg=3.352853, loss_adv=0.000708, loss_D=0.339611]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   7%|▋         | 116/1664 [00:27<06:44,  3.83it/s, loss_seg=3.352853, loss_adv=0.000708, loss_D=0.339611]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   7%|▋         | 116/1664 [00:27<06:44,  3.83it/s, loss_seg=3.449179, loss_adv=0.000726, loss_D=0.331113]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   7%|▋         | 120/1664 [00:28<05:54,  4.36it/s, loss_seg=3.449179, loss_adv=0.000726, loss_D=0.331113]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   7%|▋         | 120/1664 [00:28<05:54,  4.36it/s, loss_seg=3.331503, loss_adv=0.000728, loss_D=0.330631]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   7%|▋         | 124/1664 [00:29<05:45,  4.46it/s, loss_seg=3.331503, loss_adv=0.000728, loss_D=0.330631]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   7%|▋         | 124/1664 [00:29<05:45,  4.46it/s, loss_seg=3.096107, loss_adv=0.000706, loss_D=0.341238]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   8%|▊         | 128/1664 [00:29<05:19,  4.80it/s, loss_seg=3.096107, loss_adv=0.000706, loss_D=0.341238]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   8%|▊         | 128/1664 [00:29<05:19,  4.80it/s, loss_seg=3.287476, loss_adv=0.000684, loss_D=0.352123]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   8%|▊         | 132/1664 [00:30<05:11,  4.92it/s, loss_seg=3.287476, loss_adv=0.000684, loss_D=0.352123]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   8%|▊         | 132/1664 [00:30<05:11,  4.92it/s, loss_seg=3.175110, loss_adv=0.000676, loss_D=0.355671]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   8%|▊         | 136/1664 [00:31<04:52,  5.22it/s, loss_seg=3.175110, loss_adv=0.000676, loss_D=0.355671]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   8%|▊         | 136/1664 [00:31<04:52,  5.22it/s, loss_seg=3.095568, loss_adv=0.000689, loss_D=0.348888]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   8%|▊         | 140/1664 [00:32<05:15,  4.83it/s, loss_seg=3.095568, loss_adv=0.000689, loss_D=0.348888]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   8%|▊         | 140/1664 [00:32<05:15,  4.83it/s, loss_seg=4.728086, loss_adv=0.000694, loss_D=0.346929]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   9%|▊         | 144/1664 [00:33<05:01,  5.04it/s, loss_seg=4.728086, loss_adv=0.000694, loss_D=0.346929]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   9%|▊         | 144/1664 [00:33<05:01,  5.04it/s, loss_seg=3.436678, loss_adv=0.000702, loss_D=0.342238]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   9%|▉         | 148/1664 [00:34<05:50,  4.32it/s, loss_seg=3.436678, loss_adv=0.000702, loss_D=0.342238]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   9%|▉         | 148/1664 [00:34<05:50,  4.32it/s, loss_seg=3.403043, loss_adv=0.000688, loss_D=0.349634]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   9%|▉         | 152/1664 [00:34<05:15,  4.79it/s, loss_seg=3.403043, loss_adv=0.000688, loss_D=0.349634]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   9%|▉         | 152/1664 [00:34<05:15,  4.79it/s, loss_seg=3.506127, loss_adv=0.000665, loss_D=0.361428]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   9%|▉         | 156/1664 [00:36<06:00,  4.18it/s, loss_seg=3.506127, loss_adv=0.000665, loss_D=0.361428]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:   9%|▉         | 156/1664 [00:36<06:00,  4.18it/s, loss_seg=3.620657, loss_adv=0.000692, loss_D=0.347368]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  10%|▉         | 160/1664 [00:36<05:23,  4.65it/s, loss_seg=3.620657, loss_adv=0.000692, loss_D=0.347368]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  10%|▉         | 160/1664 [00:36<05:23,  4.65it/s, loss_seg=3.558604, loss_adv=0.000738, loss_D=0.325227]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  10%|▉         | 164/1664 [00:37<05:59,  4.17it/s, loss_seg=3.558604, loss_adv=0.000738, loss_D=0.325227]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  10%|▉         | 164/1664 [00:37<05:59,  4.17it/s, loss_seg=2.716171, loss_adv=0.000718, loss_D=0.334619]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  10%|█         | 168/1664 [00:38<05:38,  4.42it/s, loss_seg=2.716171, loss_adv=0.000718, loss_D=0.334619]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  10%|█         | 168/1664 [00:38<05:38,  4.42it/s, loss_seg=2.449697, loss_adv=0.000673, loss_D=0.357012]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  10%|█         | 172/1664 [00:40<07:10,  3.47it/s, loss_seg=2.449697, loss_adv=0.000673, loss_D=0.357012]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  10%|█         | 172/1664 [00:40<07:10,  3.47it/s, loss_seg=3.619916, loss_adv=0.000659, loss_D=0.365057]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  11%|█         | 176/1664 [00:41<06:15,  3.96it/s, loss_seg=3.619916, loss_adv=0.000659, loss_D=0.365057]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  11%|█         | 176/1664 [00:41<06:15,  3.96it/s, loss_seg=3.704409, loss_adv=0.000738, loss_D=0.326388]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  11%|█         | 180/1664 [00:42<06:11,  4.00it/s, loss_seg=3.704409, loss_adv=0.000738, loss_D=0.326388]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  11%|█         | 180/1664 [00:42<06:11,  4.00it/s, loss_seg=3.240477, loss_adv=0.000768, loss_D=0.313357]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  11%|█         | 184/1664 [00:42<05:32,  4.45it/s, loss_seg=3.240477, loss_adv=0.000768, loss_D=0.313357]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  11%|█         | 184/1664 [00:42<05:32,  4.45it/s, loss_seg=2.952956, loss_adv=0.000688, loss_D=0.349827]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  11%|█▏        | 188/1664 [00:43<05:32,  4.44it/s, loss_seg=2.952956, loss_adv=0.000688, loss_D=0.349827]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  11%|█▏        | 188/1664 [00:43<05:32,  4.44it/s, loss_seg=3.327030, loss_adv=0.000598, loss_D=0.400235]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▏        | 192/1664 [00:44<05:08,  4.77it/s, loss_seg=3.327030, loss_adv=0.000598, loss_D=0.400235]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▏        | 192/1664 [00:44<05:08,  4.77it/s, loss_seg=2.923211, loss_adv=0.000659, loss_D=0.364613]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▏        | 196/1664 [00:45<05:12,  4.70it/s, loss_seg=2.923211, loss_adv=0.000659, loss_D=0.364613]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▏        | 196/1664 [00:45<05:12,  4.70it/s, loss_seg=3.738742, loss_adv=0.000785, loss_D=0.305307]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▏        | 200/1664 [00:45<04:51,  5.03it/s, loss_seg=3.738742, loss_adv=0.000785, loss_D=0.305307]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▏        | 200/1664 [00:45<04:51,  5.03it/s, loss_seg=4.713251, loss_adv=0.000750, loss_D=0.320257]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▏        | 204/1664 [00:46<04:51,  5.01it/s, loss_seg=4.713251, loss_adv=0.000750, loss_D=0.320257]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▏        | 204/1664 [00:46<04:51,  5.01it/s, loss_seg=3.734196, loss_adv=0.000664, loss_D=0.361847]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▎        | 208/1664 [00:47<04:50,  5.02it/s, loss_seg=3.734196, loss_adv=0.000664, loss_D=0.361847]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  12%|█▎        | 208/1664 [00:47<04:50,  5.02it/s, loss_seg=3.316267, loss_adv=0.000620, loss_D=0.386978]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  13%|█▎        | 212/1664 [00:48<05:18,  4.56it/s, loss_seg=3.316267, loss_adv=0.000620, loss_D=0.386978]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  13%|█▎        | 212/1664 [00:48<05:18,  4.56it/s, loss_seg=3.549347, loss_adv=0.000670, loss_D=0.358520]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  13%|█▎        | 216/1664 [00:49<04:49,  5.01it/s, loss_seg=3.549347, loss_adv=0.000670, loss_D=0.358520]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  13%|█▎        | 216/1664 [00:49<04:49,  5.01it/s, loss_seg=2.874227, loss_adv=0.000740, loss_D=0.324243]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  13%|█▎        | 220/1664 [00:50<05:20,  4.51it/s, loss_seg=2.874227, loss_adv=0.000740, loss_D=0.324243]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  13%|█▎        | 220/1664 [00:50<05:20,  4.51it/s, loss_seg=2.754149, loss_adv=0.000768, loss_D=0.311913]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  13%|█▎        | 224/1664 [00:51<04:57,  4.84it/s, loss_seg=2.754149, loss_adv=0.000768, loss_D=0.311913]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  13%|█▎        | 224/1664 [00:51<04:57,  4.84it/s, loss_seg=3.327124, loss_adv=0.000711, loss_D=0.337754]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  14%|█▎        | 228/1664 [00:52<06:22,  3.76it/s, loss_seg=3.327124, loss_adv=0.000711, loss_D=0.337754]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  14%|█▎        | 228/1664 [00:52<06:22,  3.76it/s, loss_seg=2.776350, loss_adv=0.000657, loss_D=0.365638]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  14%|█▍        | 232/1664 [00:53<05:54,  4.04it/s, loss_seg=2.776350, loss_adv=0.000657, loss_D=0.365638]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  14%|█▍        | 232/1664 [00:53<05:54,  4.04it/s, loss_seg=2.379105, loss_adv=0.000648, loss_D=0.370564]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  14%|█▍        | 236/1664 [00:54<06:49,  3.49it/s, loss_seg=2.379105, loss_adv=0.000648, loss_D=0.370564]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  14%|█▍        | 236/1664 [00:54<06:49,  3.49it/s, loss_seg=2.979709, loss_adv=0.000659, loss_D=0.364443]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  14%|█▍        | 240/1664 [00:55<06:01,  3.94it/s, loss_seg=2.979709, loss_adv=0.000659, loss_D=0.364443]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  14%|█▍        | 240/1664 [00:55<06:01,  3.94it/s, loss_seg=3.961764, loss_adv=0.000689, loss_D=0.348515]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  15%|█▍        | 244/1664 [00:56<05:30,  4.29it/s, loss_seg=3.961764, loss_adv=0.000689, loss_D=0.348515]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  15%|█▍        | 244/1664 [00:56<05:30,  4.29it/s, loss_seg=3.517075, loss_adv=0.000713, loss_D=0.337155]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  15%|█▍        | 248/1664 [00:57<05:05,  4.63it/s, loss_seg=3.517075, loss_adv=0.000713, loss_D=0.337155]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  15%|█▍        | 248/1664 [00:57<05:05,  4.63it/s, loss_seg=3.683394, loss_adv=0.000728, loss_D=0.329786]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  15%|█▌        | 252/1664 [00:58<05:15,  4.47it/s, loss_seg=3.683394, loss_adv=0.000728, loss_D=0.329786]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  15%|█▌        | 252/1664 [00:58<05:15,  4.47it/s, loss_seg=3.519464, loss_adv=0.000730, loss_D=0.328978]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  15%|█▌        | 256/1664 [00:58<04:45,  4.93it/s, loss_seg=3.519464, loss_adv=0.000730, loss_D=0.328978]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  15%|█▌        | 256/1664 [00:58<04:45,  4.93it/s, loss_seg=2.766776, loss_adv=0.000716, loss_D=0.335446]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  16%|█▌        | 260/1664 [00:59<04:39,  5.02it/s, loss_seg=2.766776, loss_adv=0.000716, loss_D=0.335446]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  16%|█▌        | 260/1664 [00:59<04:39,  5.02it/s, loss_seg=2.096701, loss_adv=0.000701, loss_D=0.342788]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  16%|█▌        | 264/1664 [01:00<04:27,  5.24it/s, loss_seg=2.096701, loss_adv=0.000701, loss_D=0.342788]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  16%|█▌        | 264/1664 [01:00<04:27,  5.24it/s, loss_seg=2.766303, loss_adv=0.000685, loss_D=0.350661]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  16%|█▌        | 268/1664 [01:01<04:57,  4.70it/s, loss_seg=2.766303, loss_adv=0.000685, loss_D=0.350661]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  16%|█▌        | 268/1664 [01:01<04:57,  4.70it/s, loss_seg=3.627605, loss_adv=0.000677, loss_D=0.354728]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  16%|█▋        | 272/1664 [01:02<05:06,  4.54it/s, loss_seg=3.627605, loss_adv=0.000677, loss_D=0.354728]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  16%|█▋        | 272/1664 [01:02<05:06,  4.54it/s, loss_seg=3.253142, loss_adv=0.000675, loss_D=0.355751]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  17%|█▋        | 276/1664 [01:02<04:42,  4.91it/s, loss_seg=3.253142, loss_adv=0.000675, loss_D=0.355751]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  17%|█▋        | 276/1664 [01:02<04:42,  4.91it/s, loss_seg=2.585594, loss_adv=0.000685, loss_D=0.350663]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  17%|█▋        | 280/1664 [01:03<05:09,  4.48it/s, loss_seg=2.585594, loss_adv=0.000685, loss_D=0.350663]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  17%|█▋        | 280/1664 [01:03<05:09,  4.48it/s, loss_seg=2.649945, loss_adv=0.000694, loss_D=0.346343]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  17%|█▋        | 284/1664 [01:04<04:43,  4.86it/s, loss_seg=2.649945, loss_adv=0.000694, loss_D=0.346343]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  17%|█▋        | 284/1664 [01:04<04:43,  4.86it/s, loss_seg=2.507051, loss_adv=0.000703, loss_D=0.341688]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  17%|█▋        | 288/1664 [01:05<05:11,  4.41it/s, loss_seg=2.507051, loss_adv=0.000703, loss_D=0.341688]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  17%|█▋        | 288/1664 [01:05<05:11,  4.41it/s, loss_seg=2.527083, loss_adv=0.000707, loss_D=0.339757]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  18%|█▊        | 292/1664 [01:06<05:00,  4.56it/s, loss_seg=2.527083, loss_adv=0.000707, loss_D=0.339757]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  18%|█▊        | 292/1664 [01:06<05:00,  4.56it/s, loss_seg=2.223375, loss_adv=0.000708, loss_D=0.339285]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  18%|█▊        | 296/1664 [01:08<06:24,  3.56it/s, loss_seg=2.223375, loss_adv=0.000708, loss_D=0.339285]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  18%|█▊        | 296/1664 [01:08<06:24,  3.56it/s, loss_seg=2.675031, loss_adv=0.000705, loss_D=0.340570]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  18%|█▊        | 300/1664 [01:08<05:41,  3.99it/s, loss_seg=2.675031, loss_adv=0.000705, loss_D=0.340570]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  18%|█▊        | 300/1664 [01:08<05:41,  3.99it/s, loss_seg=2.127209, loss_adv=0.000696, loss_D=0.345086]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  18%|█▊        | 304/1664 [01:09<05:51,  3.87it/s, loss_seg=2.127209, loss_adv=0.000696, loss_D=0.345086]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  18%|█▊        | 304/1664 [01:09<05:51,  3.87it/s, loss_seg=3.466374, loss_adv=0.000685, loss_D=0.350839]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▊        | 308/1664 [01:10<05:06,  4.43it/s, loss_seg=3.466374, loss_adv=0.000685, loss_D=0.350839]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▊        | 308/1664 [01:10<05:06,  4.43it/s, loss_seg=2.554128, loss_adv=0.000675, loss_D=0.355996]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▉        | 312/1664 [01:11<05:06,  4.42it/s, loss_seg=2.554128, loss_adv=0.000675, loss_D=0.355996]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▉        | 312/1664 [01:11<05:06,  4.42it/s, loss_seg=2.048806, loss_adv=0.000673, loss_D=0.356901]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▉        | 316/1664 [01:12<04:37,  4.86it/s, loss_seg=2.048806, loss_adv=0.000673, loss_D=0.356901]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▉        | 316/1664 [01:12<04:37,  4.86it/s, loss_seg=2.534470, loss_adv=0.000671, loss_D=0.358517]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▉        | 320/1664 [01:13<05:32,  4.04it/s, loss_seg=2.534470, loss_adv=0.000671, loss_D=0.358517]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▉        | 320/1664 [01:13<05:32,  4.04it/s, loss_seg=2.383621, loss_adv=0.000691, loss_D=0.347989]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▉        | 324/1664 [01:14<04:53,  4.57it/s, loss_seg=2.383621, loss_adv=0.000691, loss_D=0.347989]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  19%|█▉        | 324/1664 [01:14<04:53,  4.57it/s, loss_seg=3.251602, loss_adv=0.000703, loss_D=0.341606]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  20%|█▉        | 328/1664 [01:14<04:53,  4.56it/s, loss_seg=3.251602, loss_adv=0.000703, loss_D=0.341606]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  20%|█▉        | 328/1664 [01:15<04:53,  4.56it/s, loss_seg=2.739362, loss_adv=0.000710, loss_D=0.338348]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  20%|█▉        | 332/1664 [01:15<04:25,  5.01it/s, loss_seg=2.739362, loss_adv=0.000710, loss_D=0.338348]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  20%|█▉        | 332/1664 [01:15<04:25,  5.01it/s, loss_seg=2.280249, loss_adv=0.000709, loss_D=0.338927]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  20%|██        | 336/1664 [01:16<04:47,  4.62it/s, loss_seg=2.280249, loss_adv=0.000709, loss_D=0.338927]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  20%|██        | 336/1664 [01:16<04:47,  4.62it/s, loss_seg=2.518704, loss_adv=0.000705, loss_D=0.340859]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  20%|██        | 340/1664 [01:17<04:29,  4.91it/s, loss_seg=2.518704, loss_adv=0.000705, loss_D=0.340859]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  20%|██        | 340/1664 [01:17<04:29,  4.91it/s, loss_seg=2.713886, loss_adv=0.000702, loss_D=0.342213]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  21%|██        | 344/1664 [01:18<04:44,  4.64it/s, loss_seg=2.713886, loss_adv=0.000702, loss_D=0.342213]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  21%|██        | 344/1664 [01:18<04:44,  4.64it/s, loss_seg=3.130518, loss_adv=0.000690, loss_D=0.348328]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  21%|██        | 348/1664 [01:19<04:29,  4.89it/s, loss_seg=3.130518, loss_adv=0.000690, loss_D=0.348328]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  21%|██        | 348/1664 [01:19<04:29,  4.89it/s, loss_seg=2.835987, loss_adv=0.000693, loss_D=0.346932]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  21%|██        | 352/1664 [01:20<05:30,  3.97it/s, loss_seg=2.835987, loss_adv=0.000693, loss_D=0.346932]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  21%|██        | 352/1664 [01:20<05:30,  3.97it/s, loss_seg=3.083143, loss_adv=0.000698, loss_D=0.344393]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  21%|██▏       | 356/1664 [01:21<05:08,  4.25it/s, loss_seg=3.083143, loss_adv=0.000698, loss_D=0.344393]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  21%|██▏       | 356/1664 [01:21<05:08,  4.25it/s, loss_seg=2.207816, loss_adv=0.000699, loss_D=0.343822]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  22%|██▏       | 360/1664 [01:22<05:54,  3.68it/s, loss_seg=2.207816, loss_adv=0.000699, loss_D=0.343822]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  22%|██▏       | 360/1664 [01:22<05:54,  3.68it/s, loss_seg=3.942729, loss_adv=0.000690, loss_D=0.348181]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  22%|██▏       | 364/1664 [01:23<05:11,  4.18it/s, loss_seg=3.942729, loss_adv=0.000690, loss_D=0.348181]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  22%|██▏       | 364/1664 [01:23<05:11,  4.18it/s, loss_seg=2.436250, loss_adv=0.000689, loss_D=0.349085]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  22%|██▏       | 368/1664 [01:24<05:46,  3.74it/s, loss_seg=2.436250, loss_adv=0.000689, loss_D=0.349085]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  22%|██▏       | 368/1664 [01:24<05:46,  3.74it/s, loss_seg=2.738816, loss_adv=0.000685, loss_D=0.350690]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  22%|██▏       | 372/1664 [01:25<05:03,  4.25it/s, loss_seg=2.738816, loss_adv=0.000685, loss_D=0.350690]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  22%|██▏       | 372/1664 [01:25<05:03,  4.25it/s, loss_seg=1.979343, loss_adv=0.000682, loss_D=0.352108]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  23%|██▎       | 376/1664 [01:25<04:37,  4.65it/s, loss_seg=1.979343, loss_adv=0.000682, loss_D=0.352108]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  23%|██▎       | 376/1664 [01:25<04:37,  4.65it/s, loss_seg=2.528638, loss_adv=0.000685, loss_D=0.350841]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  23%|██▎       | 380/1664 [01:26<04:17,  4.98it/s, loss_seg=2.528638, loss_adv=0.000685, loss_D=0.350841]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  23%|██▎       | 380/1664 [01:26<04:17,  4.98it/s, loss_seg=2.560079, loss_adv=0.000684, loss_D=0.351410]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  23%|██▎       | 384/1664 [01:27<04:48,  4.44it/s, loss_seg=2.560079, loss_adv=0.000684, loss_D=0.351410]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  23%|██▎       | 384/1664 [01:27<04:48,  4.44it/s, loss_seg=2.544032, loss_adv=0.000692, loss_D=0.347251]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  23%|██▎       | 388/1664 [01:28<04:28,  4.75it/s, loss_seg=2.544032, loss_adv=0.000692, loss_D=0.347251]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  23%|██▎       | 388/1664 [01:28<04:28,  4.75it/s, loss_seg=2.366616, loss_adv=0.000708, loss_D=0.339414]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  24%|██▎       | 392/1664 [01:29<04:13,  5.01it/s, loss_seg=2.366616, loss_adv=0.000708, loss_D=0.339414]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  24%|██▎       | 392/1664 [01:29<04:13,  5.01it/s, loss_seg=3.667044, loss_adv=0.000716, loss_D=0.335455]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  24%|██▍       | 396/1664 [01:29<04:01,  5.24it/s, loss_seg=3.667044, loss_adv=0.000716, loss_D=0.335455]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  24%|██▍       | 396/1664 [01:29<04:01,  5.24it/s, loss_seg=2.873984, loss_adv=0.000710, loss_D=0.338247]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  24%|██▍       | 400/1664 [01:30<04:25,  4.76it/s, loss_seg=2.873984, loss_adv=0.000710, loss_D=0.338247]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  24%|██▍       | 400/1664 [01:30<04:25,  4.76it/s, loss_seg=4.335474, loss_adv=0.000690, loss_D=0.348164]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  24%|██▍       | 404/1664 [01:31<04:06,  5.10it/s, loss_seg=4.335474, loss_adv=0.000690, loss_D=0.348164]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  24%|██▍       | 404/1664 [01:31<04:06,  5.10it/s, loss_seg=2.660564, loss_adv=0.000689, loss_D=0.348890]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▍       | 408/1664 [01:32<04:12,  4.98it/s, loss_seg=2.660564, loss_adv=0.000689, loss_D=0.348890]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▍       | 408/1664 [01:32<04:12,  4.98it/s, loss_seg=2.234936, loss_adv=0.000689, loss_D=0.348712]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▍       | 412/1664 [01:33<04:05,  5.10it/s, loss_seg=2.234936, loss_adv=0.000689, loss_D=0.348712]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▍       | 412/1664 [01:33<04:05,  5.10it/s, loss_seg=2.498812, loss_adv=0.000687, loss_D=0.349625]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▌       | 416/1664 [01:34<05:24,  3.84it/s, loss_seg=2.498812, loss_adv=0.000687, loss_D=0.349625]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▌       | 416/1664 [01:34<05:24,  3.84it/s, loss_seg=3.665157, loss_adv=0.000698, loss_D=0.344190]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▌       | 420/1664 [01:35<04:59,  4.15it/s, loss_seg=3.665157, loss_adv=0.000698, loss_D=0.344190]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▌       | 420/1664 [01:35<04:59,  4.15it/s, loss_seg=1.769525, loss_adv=0.000710, loss_D=0.338229]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▌       | 424/1664 [01:37<05:51,  3.53it/s, loss_seg=1.769525, loss_adv=0.000710, loss_D=0.338229]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  25%|██▌       | 424/1664 [01:37<05:51,  3.53it/s, loss_seg=2.311394, loss_adv=0.000712, loss_D=0.337305]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  26%|██▌       | 428/1664 [01:37<05:05,  4.05it/s, loss_seg=2.311394, loss_adv=0.000712, loss_D=0.337305]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  26%|██▌       | 428/1664 [01:37<05:05,  4.05it/s, loss_seg=1.838778, loss_adv=0.000707, loss_D=0.339961]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  26%|██▌       | 432/1664 [01:38<04:50,  4.23it/s, loss_seg=1.838778, loss_adv=0.000707, loss_D=0.339961]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  26%|██▌       | 432/1664 [01:38<04:50,  4.23it/s, loss_seg=3.492328, loss_adv=0.000691, loss_D=0.347741]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  26%|██▌       | 436/1664 [01:39<04:26,  4.61it/s, loss_seg=3.492328, loss_adv=0.000691, loss_D=0.347741]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  26%|██▌       | 436/1664 [01:39<04:26,  4.61it/s, loss_seg=2.178421, loss_adv=0.000679, loss_D=0.353590]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  26%|██▋       | 440/1664 [01:40<04:36,  4.42it/s, loss_seg=2.178421, loss_adv=0.000679, loss_D=0.353590]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  26%|██▋       | 440/1664 [01:40<04:36,  4.42it/s, loss_seg=3.950839, loss_adv=0.000686, loss_D=0.350209]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  27%|██▋       | 444/1664 [01:40<04:12,  4.82it/s, loss_seg=3.950839, loss_adv=0.000686, loss_D=0.350209]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  27%|██▋       | 444/1664 [01:40<04:12,  4.82it/s, loss_seg=1.916476, loss_adv=0.000705, loss_D=0.340580]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  27%|██▋       | 448/1664 [01:41<04:18,  4.71it/s, loss_seg=1.916476, loss_adv=0.000705, loss_D=0.340580]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  27%|██▋       | 448/1664 [01:41<04:18,  4.71it/s, loss_seg=2.518351, loss_adv=0.000717, loss_D=0.335169]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  27%|██▋       | 452/1664 [01:42<03:52,  5.21it/s, loss_seg=2.518351, loss_adv=0.000717, loss_D=0.335169]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  27%|██▋       | 452/1664 [01:42<03:52,  5.21it/s, loss_seg=3.065233, loss_adv=0.000719, loss_D=0.334051]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  27%|██▋       | 456/1664 [01:43<04:01,  5.00it/s, loss_seg=3.065233, loss_adv=0.000719, loss_D=0.334051]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  27%|██▋       | 456/1664 [01:43<04:01,  5.00it/s, loss_seg=2.041721, loss_adv=0.000708, loss_D=0.339360]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  28%|██▊       | 460/1664 [01:43<03:44,  5.37it/s, loss_seg=2.041721, loss_adv=0.000708, loss_D=0.339360]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  28%|██▊       | 460/1664 [01:43<03:44,  5.37it/s, loss_seg=2.362221, loss_adv=0.000696, loss_D=0.345507]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  28%|██▊       | 464/1664 [01:45<04:27,  4.48it/s, loss_seg=2.362221, loss_adv=0.000696, loss_D=0.345507]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  28%|██▊       | 464/1664 [01:45<04:27,  4.48it/s, loss_seg=2.801886, loss_adv=0.000682, loss_D=0.352090]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  28%|██▊       | 468/1664 [01:45<04:03,  4.90it/s, loss_seg=2.801886, loss_adv=0.000682, loss_D=0.352090]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  28%|██▊       | 468/1664 [01:45<04:03,  4.90it/s, loss_seg=2.325778, loss_adv=0.000680, loss_D=0.353222]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  28%|██▊       | 472/1664 [01:47<04:47,  4.14it/s, loss_seg=2.325778, loss_adv=0.000680, loss_D=0.353222]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  28%|██▊       | 472/1664 [01:47<04:47,  4.14it/s, loss_seg=2.261177, loss_adv=0.000683, loss_D=0.351870]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  29%|██▊       | 476/1664 [01:47<04:27,  4.45it/s, loss_seg=2.261177, loss_adv=0.000683, loss_D=0.351870]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  29%|██▊       | 476/1664 [01:47<04:27,  4.45it/s, loss_seg=2.121322, loss_adv=0.000700, loss_D=0.343474]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  29%|██▉       | 480/1664 [01:49<05:48,  3.40it/s, loss_seg=2.121322, loss_adv=0.000700, loss_D=0.343474]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  29%|██▉       | 480/1664 [01:49<05:48,  3.40it/s, loss_seg=3.537431, loss_adv=0.000702, loss_D=0.342728]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  29%|██▉       | 484/1664 [01:50<05:10,  3.80it/s, loss_seg=3.537431, loss_adv=0.000702, loss_D=0.342728]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  29%|██▉       | 484/1664 [01:50<05:10,  3.80it/s, loss_seg=2.277554, loss_adv=0.000703, loss_D=0.341896]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  29%|██▉       | 488/1664 [01:51<05:21,  3.66it/s, loss_seg=2.277554, loss_adv=0.000703, loss_D=0.341896]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  29%|██▉       | 488/1664 [01:51<05:21,  3.66it/s, loss_seg=2.438476, loss_adv=0.000693, loss_D=0.346960]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  30%|██▉       | 492/1664 [01:52<04:37,  4.22it/s, loss_seg=2.438476, loss_adv=0.000693, loss_D=0.346960]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  30%|██▉       | 492/1664 [01:52<04:37,  4.22it/s, loss_seg=2.587986, loss_adv=0.000675, loss_D=0.356066]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  30%|██▉       | 496/1664 [01:53<04:50,  4.02it/s, loss_seg=2.587986, loss_adv=0.000675, loss_D=0.356066]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  30%|██▉       | 496/1664 [01:53<04:50,  4.02it/s, loss_seg=2.553542, loss_adv=0.000671, loss_D=0.358258]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  30%|███       | 500/1664 [01:53<04:22,  4.44it/s, loss_seg=2.553542, loss_adv=0.000671, loss_D=0.358258]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  30%|███       | 500/1664 [01:53<04:22,  4.44it/s, loss_seg=2.262271, loss_adv=0.000676, loss_D=0.355494]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  30%|███       | 504/1664 [01:54<04:24,  4.39it/s, loss_seg=2.262271, loss_adv=0.000676, loss_D=0.355494]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  30%|███       | 504/1664 [01:54<04:24,  4.39it/s, loss_seg=4.966677, loss_adv=0.000684, loss_D=0.351500]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███       | 508/1664 [01:55<04:00,  4.81it/s, loss_seg=4.966677, loss_adv=0.000684, loss_D=0.351500]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███       | 508/1664 [01:55<04:00,  4.81it/s, loss_seg=2.810930, loss_adv=0.000688, loss_D=0.349495]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███       | 512/1664 [01:56<03:58,  4.84it/s, loss_seg=2.810930, loss_adv=0.000688, loss_D=0.349495]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███       | 512/1664 [01:56<03:58,  4.84it/s, loss_seg=1.960860, loss_adv=0.000700, loss_D=0.343188]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███       | 516/1664 [01:57<03:44,  5.12it/s, loss_seg=1.960860, loss_adv=0.000700, loss_D=0.343188]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███       | 516/1664 [01:57<03:44,  5.12it/s, loss_seg=1.874068, loss_adv=0.000714, loss_D=0.336814]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███▏      | 520/1664 [01:57<03:53,  4.89it/s, loss_seg=1.874068, loss_adv=0.000714, loss_D=0.336814]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███▏      | 520/1664 [01:57<03:53,  4.89it/s, loss_seg=2.762506, loss_adv=0.000709, loss_D=0.338830]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███▏      | 524/1664 [01:58<03:42,  5.13it/s, loss_seg=2.762506, loss_adv=0.000709, loss_D=0.338830]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  31%|███▏      | 524/1664 [01:58<03:42,  5.13it/s, loss_seg=2.178222, loss_adv=0.000695, loss_D=0.345911]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  32%|███▏      | 528/1664 [01:59<03:50,  4.94it/s, loss_seg=2.178222, loss_adv=0.000695, loss_D=0.345911]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  32%|███▏      | 528/1664 [01:59<03:50,  4.94it/s, loss_seg=2.363493, loss_adv=0.000684, loss_D=0.351043]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  32%|███▏      | 532/1664 [02:00<03:36,  5.24it/s, loss_seg=2.363493, loss_adv=0.000684, loss_D=0.351043]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  32%|███▏      | 532/1664 [02:00<03:36,  5.24it/s, loss_seg=2.170912, loss_adv=0.000678, loss_D=0.354128]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  32%|███▏      | 536/1664 [02:01<03:53,  4.83it/s, loss_seg=2.170912, loss_adv=0.000678, loss_D=0.354128]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  32%|███▏      | 536/1664 [02:01<03:53,  4.83it/s, loss_seg=2.365009, loss_adv=0.000685, loss_D=0.350658]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  32%|███▏      | 540/1664 [02:02<03:57,  4.74it/s, loss_seg=2.365009, loss_adv=0.000685, loss_D=0.350658]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  32%|███▏      | 540/1664 [02:02<03:57,  4.74it/s, loss_seg=2.078828, loss_adv=0.000686, loss_D=0.350138]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  33%|███▎      | 544/1664 [02:03<05:20,  3.50it/s, loss_seg=2.078828, loss_adv=0.000686, loss_D=0.350138]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  33%|███▎      | 544/1664 [02:03<05:20,  3.50it/s, loss_seg=2.742049, loss_adv=0.000687, loss_D=0.349565]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  33%|███▎      | 548/1664 [02:04<04:46,  3.90it/s, loss_seg=2.742049, loss_adv=0.000687, loss_D=0.349565]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  33%|███▎      | 548/1664 [02:04<04:46,  3.90it/s, loss_seg=2.305037, loss_adv=0.000692, loss_D=0.347298]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  33%|███▎      | 552/1664 [02:05<04:39,  3.98it/s, loss_seg=2.305037, loss_adv=0.000692, loss_D=0.347298]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  33%|███▎      | 552/1664 [02:05<04:39,  3.98it/s, loss_seg=2.237793, loss_adv=0.000694, loss_D=0.346221]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  33%|███▎      | 556/1664 [02:06<04:09,  4.45it/s, loss_seg=2.237793, loss_adv=0.000694, loss_D=0.346221]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  33%|███▎      | 556/1664 [02:06<04:09,  4.45it/s, loss_seg=2.059361, loss_adv=0.000696, loss_D=0.345371]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  34%|███▎      | 560/1664 [02:07<04:25,  4.16it/s, loss_seg=2.059361, loss_adv=0.000696, loss_D=0.345371]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  34%|███▎      | 560/1664 [02:07<04:25,  4.16it/s, loss_seg=2.721210, loss_adv=0.000699, loss_D=0.343851]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  34%|███▍      | 564/1664 [02:08<04:04,  4.51it/s, loss_seg=2.721210, loss_adv=0.000699, loss_D=0.343851]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  34%|███▍      | 564/1664 [02:08<04:04,  4.51it/s, loss_seg=1.946223, loss_adv=0.000703, loss_D=0.341732]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  34%|███▍      | 568/1664 [02:08<04:01,  4.54it/s, loss_seg=1.946223, loss_adv=0.000703, loss_D=0.341732]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  34%|███▍      | 568/1664 [02:08<04:01,  4.54it/s, loss_seg=2.383320, loss_adv=0.000707, loss_D=0.339805]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  34%|███▍      | 572/1664 [02:09<03:43,  4.88it/s, loss_seg=2.383320, loss_adv=0.000707, loss_D=0.339805]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  34%|███▍      | 572/1664 [02:09<03:43,  4.88it/s, loss_seg=2.538391, loss_adv=0.000709, loss_D=0.338703]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  35%|███▍      | 576/1664 [02:10<03:58,  4.56it/s, loss_seg=2.538391, loss_adv=0.000709, loss_D=0.338703]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  35%|███▍      | 576/1664 [02:10<03:58,  4.56it/s, loss_seg=1.985847, loss_adv=0.000707, loss_D=0.339818]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  35%|███▍      | 580/1664 [02:11<03:40,  4.92it/s, loss_seg=1.985847, loss_adv=0.000707, loss_D=0.339818]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  35%|███▍      | 580/1664 [02:11<03:40,  4.92it/s, loss_seg=2.790513, loss_adv=0.000701, loss_D=0.342631]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  35%|███▌      | 584/1664 [02:12<04:02,  4.46it/s, loss_seg=2.790513, loss_adv=0.000701, loss_D=0.342631]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  35%|███▌      | 584/1664 [02:12<04:02,  4.46it/s, loss_seg=2.386923, loss_adv=0.000694, loss_D=0.346242]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  35%|███▌      | 588/1664 [02:12<03:34,  5.01it/s, loss_seg=2.386923, loss_adv=0.000694, loss_D=0.346242]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  35%|███▌      | 588/1664 [02:12<03:34,  5.01it/s, loss_seg=2.049841, loss_adv=0.000685, loss_D=0.350670]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  36%|███▌      | 592/1664 [02:13<03:41,  4.83it/s, loss_seg=2.049841, loss_adv=0.000685, loss_D=0.350670]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  36%|███▌      | 592/1664 [02:13<03:41,  4.83it/s, loss_seg=2.198722, loss_adv=0.000685, loss_D=0.350592]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  36%|███▌      | 596/1664 [02:14<03:33,  5.00it/s, loss_seg=2.198722, loss_adv=0.000685, loss_D=0.350592]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  36%|███▌      | 596/1664 [02:14<03:33,  5.00it/s, loss_seg=2.185629, loss_adv=0.000684, loss_D=0.351325]
#
#
# epoch 1, lr 0.005000, lr_discriminator 0.001000:  36%|███▌      | 600/1664 [02:16<04:27,  3.98it/s, loss_seg=2.185629, loss_adv=0.000684, loss_D=0.351325]
#
#
# ...
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  92%|█████████▏| 1528/1664 [05:47<00:28,  4.82it/s, loss_seg=1.935600, loss_adv=0.000704, loss_D=0.341706]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  92%|█████████▏| 1528/1664 [05:47<00:28,  4.82it/s, loss_seg=1.712710, loss_adv=0.000662, loss_D=0.362712]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  92%|█████████▏| 1532/1664 [05:48<00:26,  4.96it/s, loss_seg=1.712710, loss_adv=0.000662, loss_D=0.362712]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  92%|█████████▏| 1532/1664 [05:48<00:26,  4.96it/s, loss_seg=1.847852, loss_adv=0.000669, loss_D=0.358946]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  92%|█████████▏| 1536/1664 [05:49<00:26,  4.75it/s, loss_seg=1.847852, loss_adv=0.000669, loss_D=0.358946]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  92%|█████████▏| 1536/1664 [05:49<00:26,  4.75it/s, loss_seg=1.954129, loss_adv=0.000719, loss_D=0.334462]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  93%|█████████▎| 1540/1664 [05:50<00:26,  4.74it/s, loss_seg=1.954129, loss_adv=0.000719, loss_D=0.334462]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  93%|█████████▎| 1540/1664 [05:50<00:26,  4.74it/s, loss_seg=1.491227, loss_adv=0.000732, loss_D=0.328140]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  93%|█████████▎| 1544/1664 [05:51<00:30,  3.88it/s, loss_seg=1.491227, loss_adv=0.000732, loss_D=0.328140]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  93%|█████████▎| 1544/1664 [05:51<00:30,  3.88it/s, loss_seg=1.850175, loss_adv=0.000690, loss_D=0.348222]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  93%|█████████▎| 1548/1664 [05:52<00:28,  4.12it/s, loss_seg=1.850175, loss_adv=0.000690, loss_D=0.348222]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  93%|█████████▎| 1548/1664 [05:52<00:28,  4.12it/s, loss_seg=3.422994, loss_adv=0.000643, loss_D=0.372876]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  93%|█████████▎| 1552/1664 [05:54<00:31,  3.53it/s, loss_seg=3.422994, loss_adv=0.000643, loss_D=0.372876]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  93%|█████████▎| 1552/1664 [05:54<00:31,  3.53it/s, loss_seg=1.282344, loss_adv=0.000672, loss_D=0.357580]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▎| 1556/1664 [05:54<00:27,  3.95it/s, loss_seg=1.282344, loss_adv=0.000672, loss_D=0.357580]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▎| 1556/1664 [05:54<00:27,  3.95it/s, loss_seg=2.173961, loss_adv=0.000720, loss_D=0.333754]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▍| 1560/1664 [05:55<00:25,  4.02it/s, loss_seg=2.173961, loss_adv=0.000720, loss_D=0.333754]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▍| 1560/1664 [05:55<00:25,  4.02it/s, loss_seg=1.231013, loss_adv=0.000746, loss_D=0.321683]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▍| 1564/1664 [05:56<00:22,  4.39it/s, loss_seg=1.231013, loss_adv=0.000746, loss_D=0.321683]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▍| 1564/1664 [05:56<00:22,  4.39it/s, loss_seg=1.413417, loss_adv=0.000727, loss_D=0.330490]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▍| 1568/1664 [05:57<00:21,  4.43it/s, loss_seg=1.413417, loss_adv=0.000727, loss_D=0.330490]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▍| 1568/1664 [05:57<00:21,  4.43it/s, loss_seg=1.216323, loss_adv=0.000676, loss_D=0.355256]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▍| 1572/1664 [05:58<00:19,  4.69it/s, loss_seg=1.216323, loss_adv=0.000676, loss_D=0.355256]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  94%|█████████▍| 1572/1664 [05:58<00:19,  4.69it/s, loss_seg=1.053269, loss_adv=0.000657, loss_D=0.365395]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  95%|█████████▍| 1576/1664 [05:58<00:18,  4.77it/s, loss_seg=1.053269, loss_adv=0.000657, loss_D=0.365395]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  95%|█████████▍| 1576/1664 [05:58<00:18,  4.77it/s, loss_seg=1.687217, loss_adv=0.000658, loss_D=0.364703]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  95%|█████████▍| 1580/1664 [05:59<00:16,  4.95it/s, loss_seg=1.687217, loss_adv=0.000658, loss_D=0.364703]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  95%|█████████▍| 1580/1664 [05:59<00:16,  4.95it/s, loss_seg=1.127197, loss_adv=0.000694, loss_D=0.346430]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  95%|█████████▌| 1584/1664 [06:00<00:15,  5.10it/s, loss_seg=1.127197, loss_adv=0.000694, loss_D=0.346430]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  95%|█████████▌| 1584/1664 [06:00<00:15,  5.10it/s, loss_seg=1.528234, loss_adv=0.000745, loss_D=0.322085]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  95%|█████████▌| 1588/1664 [06:01<00:14,  5.28it/s, loss_seg=1.528234, loss_adv=0.000745, loss_D=0.322085]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  95%|█████████▌| 1588/1664 [06:01<00:14,  5.28it/s, loss_seg=1.516815, loss_adv=0.000751, loss_D=0.319339]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  96%|█████████▌| 1592/1664 [06:02<00:16,  4.24it/s, loss_seg=1.516815, loss_adv=0.000751, loss_D=0.319339]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  96%|█████████▌| 1592/1664 [06:02<00:16,  4.24it/s, loss_seg=1.737135, loss_adv=0.000705, loss_D=0.340874]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  96%|█████████▌| 1596/1664 [06:03<00:14,  4.57it/s, loss_seg=1.737135, loss_adv=0.000705, loss_D=0.340874]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  96%|█████████▌| 1596/1664 [06:03<00:14,  4.57it/s, loss_seg=1.795459, loss_adv=0.000663, loss_D=0.362120]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  96%|█████████▌| 1600/1664 [06:04<00:15,  4.07it/s, loss_seg=1.795459, loss_adv=0.000663, loss_D=0.362120]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  96%|█████████▌| 1600/1664 [06:04<00:15,  4.07it/s, loss_seg=1.228901, loss_adv=0.000638, loss_D=0.375847]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  96%|█████████▋| 1604/1664 [06:05<00:13,  4.30it/s, loss_seg=1.228901, loss_adv=0.000638, loss_D=0.375847]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  96%|█████████▋| 1604/1664 [06:05<00:13,  4.30it/s, loss_seg=1.320302, loss_adv=0.000646, loss_D=0.371755]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  97%|█████████▋| 1608/1664 [06:06<00:15,  3.58it/s, loss_seg=1.320302, loss_adv=0.000646, loss_D=0.371755]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  97%|█████████▋| 1608/1664 [06:06<00:15,  3.58it/s, loss_seg=1.432672, loss_adv=0.000682, loss_D=0.352264]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  97%|█████████▋| 1612/1664 [06:07<00:13,  3.82it/s, loss_seg=1.432672, loss_adv=0.000682, loss_D=0.352264]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  97%|█████████▋| 1612/1664 [06:07<00:13,  3.82it/s, loss_seg=2.515713, loss_adv=0.000704, loss_D=0.341465]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  97%|█████████▋| 1616/1664 [06:08<00:13,  3.49it/s, loss_seg=2.515713, loss_adv=0.000704, loss_D=0.341465]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  97%|█████████▋| 1616/1664 [06:09<00:13,  3.49it/s, loss_seg=1.242667, loss_adv=0.000717, loss_D=0.335107]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  97%|█████████▋| 1620/1664 [06:09<00:10,  4.03it/s, loss_seg=1.242667, loss_adv=0.000717, loss_D=0.335107]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  97%|█████████▋| 1620/1664 [06:09<00:10,  4.03it/s, loss_seg=3.333374, loss_adv=0.000713, loss_D=0.337117]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  98%|█████████▊| 1624/1664 [06:10<00:09,  4.07it/s, loss_seg=3.333374, loss_adv=0.000713, loss_D=0.337117]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  98%|█████████▊| 1624/1664 [06:10<00:09,  4.07it/s, loss_seg=2.626062, loss_adv=0.000704, loss_D=0.341051]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  98%|█████████▊| 1628/1664 [06:11<00:08,  4.42it/s, loss_seg=2.626062, loss_adv=0.000704, loss_D=0.341051]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  98%|█████████▊| 1628/1664 [06:11<00:08,  4.42it/s, loss_seg=1.342262, loss_adv=0.000690, loss_D=0.348018]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  98%|█████████▊| 1632/1664 [06:12<00:07,  4.54it/s, loss_seg=1.342262, loss_adv=0.000690, loss_D=0.348018]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  98%|█████████▊| 1632/1664 [06:12<00:07,  4.54it/s, loss_seg=1.421260, loss_adv=0.000677, loss_D=0.354716]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  98%|█████████▊| 1636/1664 [06:12<00:05,  4.79it/s, loss_seg=1.421260, loss_adv=0.000677, loss_D=0.354716]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  98%|█████████▊| 1636/1664 [06:12<00:05,  4.79it/s, loss_seg=1.159364, loss_adv=0.000674, loss_D=0.356205]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  99%|█████████▊| 1640/1664 [06:13<00:05,  4.65it/s, loss_seg=1.159364, loss_adv=0.000674, loss_D=0.356205]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  99%|█████████▊| 1640/1664 [06:13<00:05,  4.65it/s, loss_seg=1.010509, loss_adv=0.000675, loss_D=0.356105]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  99%|█████████▉| 1644/1664 [06:14<00:04,  4.87it/s, loss_seg=1.010509, loss_adv=0.000675, loss_D=0.356105]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  99%|█████████▉| 1644/1664 [06:14<00:04,  4.87it/s, loss_seg=1.612219, loss_adv=0.000678, loss_D=0.354089]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  99%|█████████▉| 1648/1664 [06:15<00:03,  4.16it/s, loss_seg=1.612219, loss_adv=0.000678, loss_D=0.354089]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  99%|█████████▉| 1648/1664 [06:15<00:03,  4.16it/s, loss_seg=1.914320, loss_adv=0.000685, loss_D=0.350930]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  99%|█████████▉| 1652/1664 [06:16<00:02,  4.58it/s, loss_seg=1.914320, loss_adv=0.000685, loss_D=0.350930]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964:  99%|█████████▉| 1652/1664 [06:16<00:02,  4.58it/s, loss_seg=1.883744, loss_adv=0.000691, loss_D=0.347667]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964: 100%|█████████▉| 1656/1664 [06:17<00:01,  4.70it/s, loss_seg=1.883744, loss_adv=0.000691, loss_D=0.347667]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964: 100%|█████████▉| 1656/1664 [06:17<00:01,  4.70it/s, loss_seg=1.160218, loss_adv=0.000700, loss_D=0.346106]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964: 100%|█████████▉| 1660/1664 [06:17<00:00,  5.03it/s, loss_seg=1.160218, loss_adv=0.000700, loss_D=0.346106]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964: 100%|█████████▉| 1660/1664 [06:17<00:00,  5.03it/s, loss_seg=1.941739, loss_adv=0.000734, loss_D=0.327187]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964: 100%|██████████| 1664/1664 [06:19<00:00,  4.49it/s, loss_seg=1.941739, loss_adv=0.000734, loss_D=0.327187]
#
#
# epoch 3, lr 0.004820, lr_discriminator 0.000964: 100%|██████████| 1664/1664 [06:19<00:00,  4.39it/s, loss_seg=1.169738, loss_adv=0.000723, loss_D=0.332032]
# loss for train :
#  - Segmentation: 1.7098187569242258
#  - Adversarial: 0.0006953962807668946
#  - Discriminator: 0.34592852204178387
#   0%|          | 0/1664 [00:00<?, ?it/s]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   0%|          | 0/1664 [00:00<?, ?it/s]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   0%|          | 4/1664 [00:02<16:51,  1.64it/s]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   0%|          | 4/1664 [00:02<16:51,  1.64it/s, loss_seg=4.826578, loss_adv=0.000687, loss_D=0.349461]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   0%|          | 8/1664 [00:03<09:39,  2.86it/s, loss_seg=4.826578, loss_adv=0.000687, loss_D=0.349461]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   0%|          | 8/1664 [00:03<09:39,  2.86it/s, loss_seg=1.730145, loss_adv=0.000682, loss_D=0.352176]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   1%|          | 12/1664 [00:03<07:57,  3.46it/s, loss_seg=1.730145, loss_adv=0.000682, loss_D=0.352176]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   1%|          | 12/1664 [00:03<07:57,  3.46it/s, loss_seg=1.683160, loss_adv=0.000686, loss_D=0.350264]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   1%|          | 16/1664 [00:04<06:37,  4.15it/s, loss_seg=1.683160, loss_adv=0.000686, loss_D=0.350264]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   1%|          | 16/1664 [00:04<06:37,  4.15it/s, loss_seg=1.684385, loss_adv=0.000712, loss_D=0.337220]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   1%|          | 20/1664 [00:05<07:07,  3.85it/s, loss_seg=1.684385, loss_adv=0.000712, loss_D=0.337220]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   1%|          | 20/1664 [00:05<07:07,  3.85it/s, loss_seg=2.048205, loss_adv=0.000729, loss_D=0.329495]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   1%|▏         | 24/1664 [00:06<06:19,  4.33it/s, loss_seg=2.048205, loss_adv=0.000729, loss_D=0.329495]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   1%|▏         | 24/1664 [00:06<06:19,  4.33it/s, loss_seg=1.832352, loss_adv=0.000708, loss_D=0.339259]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   2%|▏         | 28/1664 [00:07<06:05,  4.47it/s, loss_seg=1.832352, loss_adv=0.000708, loss_D=0.339259]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   2%|▏         | 28/1664 [00:07<06:05,  4.47it/s, loss_seg=1.771928, loss_adv=0.000691, loss_D=0.347467]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   2%|▏         | 32/1664 [00:08<05:52,  4.63it/s, loss_seg=1.771928, loss_adv=0.000691, loss_D=0.347467]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   2%|▏         | 32/1664 [00:08<05:52,  4.63it/s, loss_seg=0.993559, loss_adv=0.000677, loss_D=0.354644]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   2%|▏         | 36/1664 [00:09<07:02,  3.86it/s, loss_seg=0.993559, loss_adv=0.000677, loss_D=0.354644]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   2%|▏         | 36/1664 [00:09<07:02,  3.86it/s, loss_seg=1.404132, loss_adv=0.000674, loss_D=0.356506]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   2%|▏         | 40/1664 [00:10<06:43,  4.03it/s, loss_seg=1.404132, loss_adv=0.000674, loss_D=0.356506]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   2%|▏         | 40/1664 [00:10<06:43,  4.03it/s, loss_seg=0.922562, loss_adv=0.000689, loss_D=0.348918]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   3%|▎         | 44/1664 [00:11<07:38,  3.54it/s, loss_seg=0.922562, loss_adv=0.000689, loss_D=0.348918]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   3%|▎         | 44/1664 [00:11<07:38,  3.54it/s, loss_seg=1.148156, loss_adv=0.000712, loss_D=0.337434]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   3%|▎         | 48/1664 [00:12<06:40,  4.03it/s, loss_seg=1.148156, loss_adv=0.000712, loss_D=0.337434]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   3%|▎         | 48/1664 [00:12<06:40,  4.03it/s, loss_seg=1.776002, loss_adv=0.000724, loss_D=0.331999]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   3%|▎         | 52/1664 [00:13<06:30,  4.13it/s, loss_seg=1.776002, loss_adv=0.000724, loss_D=0.331999]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   3%|▎         | 52/1664 [00:13<06:30,  4.13it/s, loss_seg=1.139634, loss_adv=0.000732, loss_D=0.328120]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   3%|▎         | 56/1664 [00:14<05:51,  4.57it/s, loss_seg=1.139634, loss_adv=0.000732, loss_D=0.328120]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   3%|▎         | 56/1664 [00:14<05:51,  4.57it/s, loss_seg=1.340142, loss_adv=0.000710, loss_D=0.338778]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   4%|▎         | 60/1664 [00:15<05:50,  4.57it/s, loss_seg=1.340142, loss_adv=0.000710, loss_D=0.338778]
#
#
# epoch 4, lr 0.004729, lr_discriminator 0.000946:   4%|▎         | 60/1664 [00:15<05:50,  4.57it/s, loss_seg=1.450195, loss_adv=0.000685, loss_D=0.351079]
